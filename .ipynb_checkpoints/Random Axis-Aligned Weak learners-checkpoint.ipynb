# %% [markdown]
# ----
# ## Goal
#
# Your goal in this assigment is to implement and test different variants of Random Forests. For this part you will be implemented randomized version of **Random Axis-Aligned** weak learner based Random Forest, i.e. you will be randomly selecting the feature from all set of features and than setting the threshold by randomly selecting a threshold.
#
# **Note** Please note that you are allowed to use only those libraries which we have discussed in the class, i.e. numpy, scipy, pandas.
#
# ## TODO:
#
# **Complete the code in files `randomForest.py`, `tree.py` and `weakLearner.py` by writing the missing code.**
#
# ## Submission Instructions
# You are required to submit the original notebook file on the Slate (with .ipynb extension), with complete set of outputs. Students failing to do so will get zero marks.
#
# *Please read each step carefully and understand it fully before proceeding with code writing*
#
# ## Plagiarism
# Any form of plagiarism will not be tolerated and result in 0 marks.

# %%
# %pylab inline
import scipy.stats
from collections import defaultdict  # default dictionary 
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)
# %load_ext autoreload 
# %autoreload 2
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import tools as t # set of tools for plotting, data splitting, etc..
import time

# %%
# Create some dummy data for testing
np.random.seed(seed=99)

# %% [markdown]
# ## Let's cook some data up for a multi-class classification problem...

# %%
#generate training and testing set...by sampling from mutli-variate Gaussian
cp=5
nclasses=2
mean1 = [-cp,-cp]
mean2 = [cp,cp]
mean3 = [cp,-cp]
mean4 = [-cp,cp]
cov = [[3.0,0.0],[0.0,3.0]] 

#create some points for the training set...
nexamples=2000
x1 = np.random.multivariate_normal(mean1,cov,nexamples/4)
x2 = np.random.multivariate_normal(mean2,cov,nexamples/4)
x3 = np.random.multivariate_normal(mean3,cov,nexamples/4)
x4 = np.random.multivariate_normal(mean4,cov,nexamples/4)

X=np.vstack((x1,x2,x3,x4))
Y=np.vstack((1*np.ones((nexamples/4,1)),2*np.ones((nexamples/4,1)),3*np.ones((nexamples/4,1)),4*np.ones((nexamples/4,1))))


plt.scatter(x1[:,0],x1[:,1], c='r', s=100)
plt.scatter(x2[:,0],x2[:,1], c='g', s=100)            
plt.scatter(x3[:,0],x3[:,1], c='b', s=100)
plt.scatter(x4[:,0],x4[:,1], c='y', s=100)            



plt.title("Multi-class Classification")
plt.xlabel("feature $x_1$")
plt.ylabel("feature $x_2$")
plt.legend(['r','g','b','y'])
fig_ml_in_10 = plt.gcf()
plt.savefig('multi-linear-class.svg',format='svg')
#create some points for the training set..

ntexamples=1000
x1 = np.random.multivariate_normal(mean1,cov,ntexamples/4)
x2 = np.random.multivariate_normal(mean2,cov,ntexamples/4)
x3 = np.random.multivariate_normal(mean3,cov,ntexamples/4)
x4 = np.random.multivariate_normal(mean4,cov,ntexamples/4)

Xt=np.vstack((x1,x2,x3,x4))
Yt=np.vstack((1*np.ones((ntexamples/4,1)),2*np.ones((ntexamples/4,1)),3*np.ones((ntexamples/4,1)),4*np.ones((ntexamples/4,1))))

# %%
import randomForest as rf

# %%
rfc=rf.RandomForest(weaklearner='Axis-Aligned-Random')
#rfc=rf.RandomForest(weaklearner='Axis-Aligned')

# %%
print X.shape, Y.shape
# Out:
# (2000, 2) (2000, 1)

# %%
#%debug        Y


rfc.train(X,Y)
# Out:
# here we will train trees
# Creating Left Child Node With 1231 Examples, and Right Node with  769 Examples
# Creating Left Child Node With 787 Examples, and Right Node with  444 Examples
# Creating Left Child Node With 337 Examples, and Right Node with  450 Examples
# C(class= 1.0 ,Purity= 1.0 )
# C(class= 3.0 ,Purity= 0.8488888888888889 )
# Creating Left Child Node With 215 Examples, and Right Node with  229 Examples
# Creating Left Child Node With 108 Examples, and Right Node with  107 Examples
# C(class= 1.0 ,Purity= 0.8518518518518519 )
# C(class= 4.0 ,Purity= 1.0 )
# Creating Left Child Node With 29 Examples, and Right Node with  200 Examples
# Creating Left Child Node With 7 Examples, and Right Node with  22 Examples
# C(class= 1.0 ,Purity= 0.42857142857142855 )
# C(class= 2.0 ,Purity= 0.7272727272727273 )
# Creating Left Child Node With 42 Examples, and Right Node with  158 Examples
# C(class= 2.0 ,Purity= 0.6190476190476191 )
# C(class= 3.0 ,Purity= 0.6012658227848101 )
# Creating Left Child Node With 363 Examples, and Right Node with  406 Examples
# C(class= 4.0 ,Purity= 1.0 )
# C(class= 2.0 ,Purity= 0.9704433497536946 )
# Creating Left Child Node With 1207 Examples, and Right Node with  793 Examples
# Creating Left Child Node With 579 Examples, and Right Node with  628 Examples
# C(class= 1.0 ,Purity= 0.846286701208981 )
# C(class= 4.0 ,Purity= 0.7961783439490446 )
# Creating Left Child Node With 356 Examples, and Right Node with  437 Examples
# C(class= 3.0 ,Purity= 1.0 )
# C(class= 2.0 ,Purity= 0.8810068649885584 )
# Creating Left Child Node With 834 Examples, and Right Node with  1166 Examples
# Creating Left Child Node With 777 Examples, and Right Node with  57 Examples
# Creating Left Child Node With 213 Examples, and Right Node with  564 Examples
# Creating Left Child Node With 84 Examples, and Right Node with  129 Examples
# C(class= 1.0 ,Purity= 1.0 )
# C(class= 3.0 ,Purity= 0.8449612403100775 )
# Creating Left Child Node With 292 Examples, and Right Node with  272 Examples
# C(class= 1.0 ,Purity= 0.9965753424657534 )
# C(class= 3.0 ,Purity= 0.9742647058823529 )
# Creating Left Child Node With 37 Examples, and Right Node with  20 Examples
# Creating Left Child Node With 30 Examples, and Right Node with  7 Examples
# Creating Left Child Node With 9 Examples, and Right Node with  21 Examples
# C(class= 3.0 ,Purity= 0.7777777777777778 )
# C(class= 3.0 ,Purity= 0.5238095238095238 )
# C(class= 3.0 ,Purity= 1.0 )
# Creating Left Child Node With 16 Examples, and Right Node with  4 Examples
# Creating Left Child Node With 13 Examples, and Right Node with  3 Examples
# C(class= 1.0 ,Purity= 0.5384615384615384 )
# C(class= 1.0 ,Purity= 1.0 )
# C(class= 3.0 ,Purity= 0.75 )
# Creating Left Child Node With 286 Examples, and Right Node with  880 Examples
# Creating Left Child Node With 155 Examples, and Right Node with  131 Examples
# Creating Left Child Node With 51 Examples, and Right Node with  104 Examples
# Creating Left Child Node With 22 Examples, and Right Node with  29 Examples
# C(class= 1.0 ,Purity= 0.9090909090909091 )
# C(class= 3.0 ,Purity= 1.0 )
# Creating Left Child Node With 84 Examples, and Right Node with  20 Examples
# C(class= 1.0 ,Purity= 0.5714285714285714 )
# C(class= 3.0 ,Purity= 0.75 )
# Creating Left Child Node With 71 Examples, and Right Node with  60 Examples
# C(class= 4.0 ,Purity= 0.9577464788732394 )
# C(class= 2.0 ,Purity= 0.85 )
# Creating Left Child Node With 461 Examples, and Right Node with  419 Examples
# C(class= 4.0 ,Purity= 0.9370932754880694 )
# C(class= 2.0 ,Purity= 1.0 )
# Creating Left Child Node With 764 Examples, and Right Node with  1236 Examples
# Creating Left Child Node With 7 Examples, and Right Node with  757 Examples
# C(class= 1.0 ,Purity= 0.7142857142857143 )
# Creating Left Child Node With 701 Examples, and Right Node with  56 Examples
# Creating Left Child Node With 383 Examples, and Right Node with  318 Examples
# C(class= 1.0 ,Purity= 0.9295039164490861 )
# C(class= 3.0 ,Purity= 1.0 )
# Creating Left Child Node With 31 Examples, and Right Node with  25 Examples
# C(class= 1.0 ,Purity= 1.0 )
# C(class= 3.0 ,Purity= 0.92 )
# Creating Left Child Node With 617 Examples, and Right Node with  619 Examples
# C(class= 4.0 ,Purity= 0.8103727714748784 )
# C(class= 2.0 ,Purity= 0.7915993537964459 )
# Creating Left Child Node With 1014 Examples, and Right Node with  986 Examples
# Creating Left Child Node With 924 Examples, and Right Node with  90 Examples
# Creating Left Child Node With 403 Examples, and Right Node with  521 Examples
# C(class= 1.0 ,Purity= 1.0 )
# C(class= 4.0 ,Purity= 0.8886756238003839 )
# Creating Left Child Node With 74 Examples, and Right Node with  16 Examples
# Creating Left Child Node With 51 Examples, and Right Node with  23 Examples
# Creating Left Child Node With 42 Examples, and Right Node with  9 Examples
# C(class= 1.0 ,Purity= 0.7619047619047619 )
# C(class= 1.0 ,Purity= 0.5555555555555556 )
# C(class= 4.0 ,Purity= 1.0 )
# Creating Left Child Node With 6 Examples, and Right Node with  10 Examples
# C(class= 4.0 ,Purity= 0.5 )
# C(class= 2.0 ,Purity= 0.5 )
# Creating Left Child Node With 494 Examples, and Right Node with  492 Examples
# C(class= 3.0 ,Purity= 0.9939271255060729 )
# C(class= 2.0 ,Purity= 0.9959349593495935 )
# Creating Left Child Node With 1367 Examples, and Right Node with  633 Examples
# Creating Left Child Node With 888 Examples, and Right Node with  479 Examples
# Creating Left Child Node With 456 Examples, and Right Node with  432 Examples
# Creating Left Child Node With 84 Examples, and Right Node with  372 Examples
# Creating Left Child Node With 51 Examples, and Right Node with  33 Examples
# C(class= 4.0 ,Purity= 0.5686274509803921 )
# C(class= 1.0 ,Purity= 0.6666666666666666 )
# Creating Left Child Node With 103 Examples, and Right Node with  269 Examples
# C(class= 4.0 ,Purity= 0.5728155339805825 )
# C(class= 4.0 ,Purity= 0.5315985130111525 )
# Creating Left Child Node With 50 Examples, and Right Node with  382 Examples
# Creating Left Child Node With 46 Examples, and Right Node with  4 Examples
# C(class= 1.0 ,Purity= 0.5652173913043478 )
# C(class= 1.0 ,Purity= 1.0 )
# Creating Left Child Node With 76 Examples, and Right Node with  306 Examples
# C(class= 1.0 ,Purity= 0.5657894736842105 )
# C(class= 1.0 ,Purity= 0.5032679738562091 )
# Creating Left Child Node With 154 Examples, and Right Node with  325 Examples
# Creating Left Child Node With 99 Examples, and Right Node with  55 Examples
# Creating Left Child Node With 53 Examples, and Right Node with  46 Examples
# C(class= 1.0 ,Purity= 0.9811320754716981 )
# C(class= 4.0 ,Purity= 1.0 )
# Creating Left Child Node With 18 Examples, and Right Node with  37 Examples
# C(class= 1.0 ,Purity= 0.3888888888888889 )
# C(class= 2.0 ,Purity= 0.5405405405405406 )
# Creating Left Child Node With 274 Examples, and Right Node with  51 Examples
# Creating Left Child Node With 142 Examples, and Right Node with  132 Examples
# C(class= 3.0 ,Purity= 0.852112676056338 )
# C(class= 2.0 ,Purity= 1.0 )
# Creating Left Child Node With 10 Examples, and Right Node with  41 Examples
# C(class= 3.0 ,Purity= 0.7 )
# C(class= 3.0 ,Purity= 0.5365853658536586 )
# Creating Left Child Node With 329 Examples, and Right Node with  304 Examples
# C(class= 3.0 ,Purity= 1.0 )
# C(class= 2.0 ,Purity= 0.993421052631579 )
# Creating Left Child Node With 981 Examples, and Right Node with  1019 Examples
# Creating Left Child Node With 905 Examples, and Right Node with  76 Examples
# Creating Left Child Node With 530 Examples, and Right Node with  375 Examples
# C(class= 1.0 ,Purity= 0.8490566037735849 )
# C(class= 4.0 ,Purity= 1.0 )
# Creating Left Child Node With 34 Examples, and Right Node with  42 Examples
# Creating Left Child Node With 29 Examples, and Right Node with  5 Examples
# Creating Left Child Node With 17 Examples, and Right Node with  12 Examples
# C(class= 1.0 ,Purity= 0.8823529411764706 )
# C(class= 4.0 ,Purity= 1.0 )
# C(class= 4.0 ,Purity= 1.0 )
# Creating Left Child Node With 20 Examples, and Right Node with  22 Examples
# C(class= 1.0 ,Purity= 0.95 )
# Creating Left Child Node With 5 Examples, and Right Node with  17 Examples
# C(class= 1.0 ,Purity= 1.0 )
# C(class= 4.0 ,Purity= 1.0 )
# Creating Left Child Node With 35 Examples, and Right Node with  984 Examples
# Creating Left Child Node With 18 Examples, and Right Node with  17 Examples
# Creating Left Child Node With 17 Examples, and Right Node with  1 Examples
# Creating Left Child Node With 8 Examples, and Right Node with  9 Examples
# C(class= 1.0 ,Purity= 0.875 )
# C(class= 3.0 ,Purity= 0.5555555555555556 )
# C(class= 2.0 ,Purity= 1.0 )
# Creating Left Child Node With 10 Examples, and Right Node with  7 Examples
# C(class= 4.0 ,Purity= 0.9 )
# C(class= 2.0 ,Purity= 1.0 )
# Creating Left Child Node With 283 Examples, and Right Node with  701 Examples
# Creating Left Child Node With 239 Examples, and Right Node with  44 Examples
# Creating Left Child Node With 112 Examples, and Right Node with  127 Examples
# C(class= 3.0 ,Purity= 0.9285714285714286 )
# C(class= 2.0 ,Purity= 1.0 )
# Creating Left Child Node With 8 Examples, and Right Node with  36 Examples
# C(class= 2.0 ,Purity= 0.75 )
# C(class= 3.0 ,Purity= 0.5833333333333334 )
# Creating Left Child Node With 378 Examples, and Right Node with  323 Examples
# C(class= 3.0 ,Purity= 0.9682539682539683 )
# C(class= 2.0 ,Purity= 1.0 )
# Creating Left Child Node With 854 Examples, and Right Node with  1146 Examples
# Creating Left Child Node With 774 Examples, and Right Node with  80 Examples
# Creating Left Child Node With 211 Examples, and Right Node with  563 Examples
# Creating Left Child Node With 9 Examples, and Right Node with  202 Examples
# C(class= 1.0 ,Purity= 0.7777777777777778 )
# Creating Left Child Node With 100 Examples, and Right Node with  102 Examples
# C(class= 1.0 ,Purity= 0.96 )
# C(class= 3.0 ,Purity= 1.0 )
# Creating Left Child Node With 315 Examples, and Right Node with  248 Examples
# C(class= 1.0 ,Purity= 0.9428571428571428 )
# C(class= 3.0 ,Purity= 1.0 )
# Creating Left Child Node With 34 Examples, and Right Node with  46 Examples
# C(class= 1.0 ,Purity= 1.0 )
# C(class= 3.0 ,Purity= 1.0 )
# Creating Left Child Node With 112 Examples, and Right Node with  1034 Examples
# Creating Left Child Node With 55 Examples, and Right Node with  57 Examples
# C(class= 1.0 ,Purity= 1.0 )
# C(class= 3.0 ,Purity= 0.9649122807017544 )
# Creating Left Child Node With 545 Examples, and Right Node with  489 Examples
# C(class= 4.0 ,Purity= 0.9174311926605505 )
# C(class= 2.0 ,Purity= 0.9488752556237219 )
# Creating Left Child Node With 1055 Examples, and Right Node with  945 Examples
# Creating Left Child Node With 500 Examples, and Right Node with  555 Examples
# C(class= 1.0 ,Purity= 0.95 )
# C(class= 3.0 ,Purity= 0.9009009009009009 )
# Creating Left Child Node With 473 Examples, and Right Node with  472 Examples
# C(class= 4.0 ,Purity= 0.9978858350951374 )
# C(class= 2.0 ,Purity= 0.9936440677966102 )
# Creating Left Child Node With 998 Examples, and Right Node with  1002 Examples
# Creating Left Child Node With 500 Examples, and Right Node with  498 Examples
# C(class= 1.0 ,Purity= 0.996 )
# C(class= 4.0 ,Purity= 0.9979919678714859 )
# Creating Left Child Node With 478 Examples, and Right Node with  524 Examples
# C(class= 3.0 ,Purity= 0.99581589958159 )
# C(class= 2.0 ,Purity= 0.9522900763358778 )

# %%
len(rfc.trees)
# Out:
# 10

# %%
# Training Confus.ion Matrix...
Yp=rfc.predict(X)
print Y.shape, len(Yp)

acc = np.sum(Y ==  np.array(Yp)) / float(Y.shape[0])
print acc
print unique(Yp)
t.print_confusion_matrix(Yp,Y)
# Out:
# (2000, 1) 2000
# 0.992
# [1. 2. 3. 4.]
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        498    0    0    2   500
# 2.0          0  498    0    2   500
# 3.0          3    9  488    0   500
# 4.0          0    0    0  500   500
# All        501  507  488  504  2000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Y ==  np.array(Yp)) / float(Y.shape[0])

assert_greater_equal(acc, 0.78)

# %%
#It might take time, a little longer than the desired
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('training-boundary-rf-raa-10trees.svg',format='svg')

# %%
#Testing Confusion Matrix...
Ypt=rfc.predict(Xt)
print Ypt.shape, len(Ypt)
t.print_confusion_matrix(Ypt,Yt)
# Out:
# (1000, 1) 1000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        247    0    0    3   250
# 2.0          0  247    0    3   250
# 3.0          4    4  242    0   250
# 4.0          0    0    0  250   250
# All        251  251  242  256  1000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Yt.flatten() ==  np.array(Ypt)) / float(Yt.shape[0]) 

assert_greater_equal(acc, 0.78)

# %%
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('testing-boundary-rf-raa-10trees.svg',format='svg')

# %%
#plt.style.use('ggplot')
#matplotlib.rcParams['figure.figsize'] = (14.0, 8.0)
t.plot_points_range(rfc,X,Y,10000)
# Out:
# (10000, 2)
# [1.0, 2.0, 3.0, 4.0]

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
ntrees=rfc.ntrees
nrows=ntrees/2
ncols=2
i=1
plt.subplots(nrows,ncols,figsize=(16,20))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    t.plot_decision_regions(X,np.squeeze(Y),clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# #### What Can You conclude

# %% [markdown]
# ## Lets Run on Nonlinear Data, The Spherical Examples...

# %%
#Get Training Data from a spherical distribution and ...
X,Y=t.get_spherical_data(N=10000)

# %%
print Y
# Out:
# [0 0 0 ... 2 2 2]

# %%
#Get Test Data 
Xtest,Ytest=t.get_spherical_data(N=5000)

# %%
rfc=rf.RandomForest(weaklearner='Axis-Aligned-Random',usebagging=False)
rfc.train(X,Y)
# Out:
# here we will train trees
# Creating Left Child Node With 21998 Examples, and Right Node with  8002 Examples
# Creating Left Child Node With 14899 Examples, and Right Node with  7099 Examples
# Creating Left Child Node With 4350 Examples, and Right Node with  10549 Examples
# Creating Left Child Node With 2400 Examples, and Right Node with  1950 Examples
# C(class= 0.0 ,Purity= 1.0 )
# C(class= 2.0 ,Purity= 0.9282051282051282 )
# Creating Left Child Node With 5910 Examples, and Right Node with  4639 Examples
# Creating Left Child Node With 2646 Examples, and Right Node with  3264 Examples
# C(class= 2.0 ,Purity= 0.8930461073318217 )
# C(class= 1.0 ,Purity= 0.8746936274509803 )
# C(class= 2.0 ,Purity= 0.6016382841129554 )
# C(class= 0.0 ,Purity= 0.7763065220453585 )
# C(class= 1.0 ,Purity= 0.7340664833791553 )
# Creating Left Child Node With 22376 Examples, and Right Node with  7624 Examples
# Creating Left Child Node With 11844 Examples, and Right Node with  10532 Examples
# Creating Left Child Node With 3579 Examples, and Right Node with  8265 Examples
# C(class= 0.0 ,Purity= 0.9960882928192233 )
# C(class= 2.0 ,Purity= 0.7153055051421657 )
# Creating Left Child Node With 4191 Examples, and Right Node with  6341 Examples
# C(class= 1.0 ,Purity= 0.7778573132903842 )
# C(class= 0.0 ,Purity= 0.6793881091310519 )
# C(class= 1.0 ,Purity= 0.7456715634837355 )
# Creating Left Child Node With 12556 Examples, and Right Node with  17444 Examples
# Creating Left Child Node With 9591 Examples, and Right Node with  2965 Examples
# C(class= 2.0 ,Purity= 0.655406109894693 )
# C(class= 0.0 ,Purity= 0.8809443507588532 )
# Creating Left Child Node With 10218 Examples, and Right Node with  7226 Examples
# Creating Left Child Node With 4587 Examples, and Right Node with  5631 Examples
# C(class= 1.0 ,Purity= 0.7471114017876608 )
# C(class= 0.0 ,Purity= 0.7044929852601669 )
# C(class= 1.0 ,Purity= 0.7484085247716579 )
# Creating Left Child Node With 4582 Examples, and Right Node with  25418 Examples
# C(class= 0.0 ,Purity= 0.872326494980358 )
# Creating Left Child Node With 7875 Examples, and Right Node with  17543 Examples
# C(class= 2.0 ,Purity= 0.7193650793650793 )
# Creating Left Child Node With 13004 Examples, and Right Node with  4539 Examples
# Creating Left Child Node With 6222 Examples, and Right Node with  6782 Examples
# C(class= 1.0 ,Purity= 0.7467052394728383 )
# C(class= 0.0 ,Purity= 0.6185491005603067 )
# C(class= 1.0 ,Purity= 0.7378277153558053 )
# Creating Left Child Node With 11881 Examples, and Right Node with  18119 Examples
# Creating Left Child Node With 8615 Examples, and Right Node with  3266 Examples
# C(class= 2.0 ,Purity= 0.681950087057458 )
# C(class= 0.0 ,Purity= 0.8860992039191672 )
# Creating Left Child Node With 10598 Examples, and Right Node with  7521 Examples
# Creating Left Child Node With 4484 Examples, and Right Node with  6114 Examples
# Creating Left Child Node With 2156 Examples, and Right Node with  2328 Examples
# C(class= 1.0 ,Purity= 0.8603896103896104 )
# Creating Left Child Node With 2045 Examples, and Right Node with  283 Examples
# C(class= 2.0 ,Purity= 0.6141809290953545 )
# C(class= 0.0 ,Purity= 0.833922261484099 )
# Creating Left Child Node With 1726 Examples, and Right Node with  4388 Examples
# C(class= 1.0 ,Purity= 0.6494785631517961 )
# C(class= 0.0 ,Purity= 0.821330902461258 )
# C(class= 1.0 ,Purity= 0.7467092142002393 )
# Creating Left Child Node With 13066 Examples, and Right Node with  16934 Examples
# Creating Left Child Node With 9832 Examples, and Right Node with  3234 Examples
# C(class= 2.0 ,Purity= 0.657546786004882 )
# C(class= 0.0 ,Purity= 0.8852813852813853 )
# Creating Left Child Node With 2464 Examples, and Right Node with  14470 Examples
# C(class= 2.0 ,Purity= 1.0 )
# C(class= 1.0 ,Purity= 0.6388389771941949 )
# Creating Left Child Node With 23187 Examples, and Right Node with  6813 Examples
# Creating Left Child Node With 10121 Examples, and Right Node with  13066 Examples
# C(class= 2.0 ,Purity= 0.6382768501136251 )
# Creating Left Child Node With 7561 Examples, and Right Node with  5505 Examples
# Creating Left Child Node With 2471 Examples, and Right Node with  5090 Examples
# Creating Left Child Node With 1883 Examples, and Right Node with  588 Examples
# C(class= 1.0 ,Purity= 0.7620817843866171 )
# C(class= 2.0 ,Purity= 0.9948979591836735 )
# Creating Left Child Node With 2452 Examples, and Right Node with  2638 Examples
# C(class= 1.0 ,Purity= 0.6092985318107668 )
# C(class= 0.0 ,Purity= 0.9943138741470812 )
# C(class= 1.0 ,Purity= 0.6372388737511353 )
# Creating Left Child Node With 4183 Examples, and Right Node with  2630 Examples
# C(class= 0.0 ,Purity= 0.830026296916089 )
# C(class= 1.0 ,Purity= 0.9391634980988594 )
# Creating Left Child Node With 19108 Examples, and Right Node with  10892 Examples
# Creating Left Child Node With 6940 Examples, and Right Node with  12168 Examples
# C(class= 2.0 ,Purity= 0.712536023054755 )
# Creating Left Child Node With 8452 Examples, and Right Node with  3716 Examples
# C(class= 1.0 ,Purity= 0.6028159015617606 )
# Creating Left Child Node With 2565 Examples, and Right Node with  1151 Examples
# C(class= 2.0 ,Purity= 0.8140350877192982 )
# C(class= 0.0 ,Purity= 0.6907037358818419 )
# Creating Left Child Node With 7939 Examples, and Right Node with  2953 Examples
# C(class= 0.0 ,Purity= 0.6897594155435194 )
# C(class= 1.0 ,Purity= 0.8675922790382662 )
# Creating Left Child Node With 22259 Examples, and Right Node with  7741 Examples
# Creating Left Child Node With 9079 Examples, and Right Node with  13180 Examples
# C(class= 2.0 ,Purity= 0.6669236700077101 )
# Creating Left Child Node With 8559 Examples, and Right Node with  4621 Examples
# Creating Left Child Node With 4573 Examples, and Right Node with  3986 Examples
# C(class= 1.0 ,Purity= 0.7756396238792915 )
# C(class= 0.0 ,Purity= 0.6615654791771199 )
# C(class= 1.0 ,Purity= 0.6223761090673015 )
# Creating Left Child Node With 5208 Examples, and Right Node with  2533 Examples
# C(class= 0.0 ,Purity= 0.8179723502304147 )
# C(class= 1.0 ,Purity= 0.9609159099881563 )
# Creating Left Child Node With 11635 Examples, and Right Node with  18365 Examples
# Creating Left Child Node With 3710 Examples, and Right Node with  7925 Examples
# C(class= 0.0 ,Purity= 0.9892183288409704 )
# C(class= 2.0 ,Purity= 0.7256782334384858 )
# Creating Left Child Node With 3738 Examples, and Right Node with  14627 Examples
# C(class= 2.0 ,Purity= 0.7504012841091493 )
# C(class= 1.0 ,Purity= 0.6006699938469953 )

# %%
#Training Confusion Matrix
Yp=rfc.predict(X)
print Y.shape, len(Yp)
t.print_confusion_matrix(Yp,Y)
# Out:
# (30000,) 30000
# Predicted   0.0    1.0   2.0    All
# Actual
# 0          7227    288  2485  10000
# 1           795   9191    14  10000
# 2           883   2713  6404  10000
# All        8905  12192  8903  30000

# %%
#Testing Confusion Matrix
Ypt=rfc.predict(Xtest)
print Y.shape, len(Ypt)
t.print_confusion_matrix(Ypt,Ytest)
# Out:
# (30000,) 15000
# Predicted   0.0   1.0   2.0    All
# Actual
# 0          3628   147  1225   5000
# 1           395  4595    10   5000
# 2           451  1366  3183   5000
# All        4474  6108  4418  15000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Y.flatten() ==  np.array(Yp)) / float(Y.shape[0]) 

assert_greater_equal(acc, 0.78)

# %%
t.plot_points_range(rfc,X,Y)

# %%
t.plot_decision_regions(X,Y,rfc)

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
ntrees=rfc.ntrees
nrows=ntrees/2
ncols=2
i=1
plt.subplots(nrows,ncols,figsize=(16,20))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    t.plot_decision_regions(X,Y,clf=tree);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout

# %% [markdown]
# ## TODO: Find Optimal Number of Trees for this data set, using cross validation...
