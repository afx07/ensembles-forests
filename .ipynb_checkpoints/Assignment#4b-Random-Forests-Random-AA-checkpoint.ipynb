# %% [markdown]
# # Assignment No 4b
# ###### *Sibt ul Hussain*
# ----
# ## Goal
#
# Your goal in this assigment is to implement and test different variants of Random Forests. For this part you will be implemented randomized version of **Random Axis-Aligned** weak learner based Random Forest, i.e. you will be randomly selecting the feature from all set of features and than setting the threshold by randomly selecting a threshold.
#
# **Note** Please note that you are allowed to use only those libraries which we have discussed in the class, i.e. numpy, scipy, pandas.
#
# ## TODO:
#
# **Complete the code in files `randomForest.py`, `tree.py` and `weakLearner.py` by writing the missing code.**
#
# ## Submission Instructions
# You are required to submit the original notebook file on the Slate (with .ipynb extension), with complete set of outputs. Students failing to do so will get zero marks.
#
# *Please read each step carefully and understand it fully before proceeding with code writing*
#
# ## Plagiarism
# Any form of plagiarism will not be tolerated and result in 0 marks.

# %%
# %pylab inline
import scipy.stats
from collections import defaultdict  # default dictionary 
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)
# %load_ext autoreload 
# %autoreload 2
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import tools as t # set of tools for plotting, data splitting, etc..
import time

# %%
# Create some dummy data for testing
np.random.seed(seed=99)

# %% [markdown]
# ## Let's cook some data up for a multi-class classification problem...

# %%
#generate training and testing set...by sampling from mutli-variate Gaussian
cp=5
nclasses=2
mean1 = [-cp,-cp]
mean2 = [cp,cp]
mean3 = [cp,-cp]
mean4 = [-cp,cp]
cov = [[3.0,0.0],[0.0,3.0]] 

#create some points for the training set...
nexamples=2000
x1 = np.random.multivariate_normal(mean1,cov,nexamples/4)
x2 = np.random.multivariate_normal(mean2,cov,nexamples/4)
x3 = np.random.multivariate_normal(mean3,cov,nexamples/4)
x4 = np.random.multivariate_normal(mean4,cov,nexamples/4)

X=np.vstack((x1,x2,x3,x4))
Y=np.vstack((1*np.ones((nexamples/4,1)),2*np.ones((nexamples/4,1)),3*np.ones((nexamples/4,1)),4*np.ones((nexamples/4,1))))


plt.scatter(x1[:,0],x1[:,1], c='r', s=100)
plt.scatter(x2[:,0],x2[:,1], c='g', s=100)            
plt.scatter(x3[:,0],x3[:,1], c='b', s=100)
plt.scatter(x4[:,0],x4[:,1], c='y', s=100)            



plt.title("Multi-class Classification")
plt.xlabel("feature $x_1$")
plt.ylabel("feature $x_2$")
plt.legend(['r','g','b','y'])
fig_ml_in_10 = plt.gcf()
plt.savefig('multi-linear-class.svg',format='svg')
#create some points for the training set..

ntexamples=1000
x1 = np.random.multivariate_normal(mean1,cov,ntexamples/4)
x2 = np.random.multivariate_normal(mean2,cov,ntexamples/4)
x3 = np.random.multivariate_normal(mean3,cov,ntexamples/4)
x4 = np.random.multivariate_normal(mean4,cov,ntexamples/4)

Xt=np.vstack((x1,x2,x3,x4))
Yt=np.vstack((1*np.ones((ntexamples/4,1)),2*np.ones((ntexamples/4,1)),3*np.ones((ntexamples/4,1)),4*np.ones((ntexamples/4,1))))

# %%
import randomForest as rf

# %%
rfc=rf.RandomForest(weaklearner='Axis-Aligned-Random')
#rfc=rf.RandomForest(weaklearner='Axis-Aligned')

# %%
print X.shape, Y.shape
# Out:
# (2000L, 2L) (2000L, 1L)

# %%
#%debug
rfc.train(X,Y)
# Out:
# Creating Left Child Node With 999 Examples, and Right Node with 1001 Examples
# Creating Left Child Node With 982 Examples, and Right Node with 17 Examples
# Creating Left Child Node With 488 Examples, and Right Node with 494 Examples
# C(posterior=[],class=1.0,Purity=0.997950819672)
# C(posterior=[],class=4.0,Purity=0.993927125506)
# Creating Left Child Node With 8 Examples, and Right Node with 9 Examples
# Creating Left Child Node With 3 Examples, and Right Node with 5 Examples
# C(posterior=[],class=1.0,Purity=1.0)
# C(posterior=[],class=4.0,Purity=1.0)
# Creating Left Child Node With 4 Examples, and Right Node with 5 Examples
# C(posterior=[],class=1.0,Purity=1.0)
# Creating Left Child Node With 3 Examples, and Right Node with 2 Examples
# C(posterior=[],class=2.0,Purity=0.666666666667)
# C(posterior=[],class=4.0,Purity=1.0)
# Creating Left Child Node With 499 Examples, and Right Node with 502 Examples
# C(posterior=[],class=3.0,Purity=0.993987975952)
# C(posterior=[],class=2.0,Purity=0.99203187251)
# Creating Left Child Node With 996 Examples, and Right Node with 1004 Examples
# Creating Left Child Node With 848 Examples, and Right Node with 148 Examples
# Creating Left Child Node With 509 Examples, and Right Node with 339 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 508 Examples
# C(posterior=[],class=1.0,Purity=1.0)
# Creating Left Child Node With 253 Examples, and Right Node with 255 Examples
# C(posterior=[],class=1.0,Purity=0.98418972332)
# C(posterior=[],class=3.0,Purity=1.0)
# Creating Left Child Node With 218 Examples, and Right Node with 121 Examples
# Creating Left Child Node With 216 Examples, and Right Node with 2 Examples
# C(posterior=[],class=1.0,Purity=0.532407407407)
# C(posterior=[],class=3.0,Purity=1.0)
# Creating Left Child Node With 75 Examples, and Right Node with 46 Examples
# C(posterior=[],class=1.0,Purity=0.96)
# C(posterior=[],class=3.0,Purity=1.0)
# Creating Left Child Node With 121 Examples, and Right Node with 27 Examples
# Creating Left Child Node With 49 Examples, and Right Node with 72 Examples
# C(posterior=[],class=1.0,Purity=0.979591836735)
# C(posterior=[],class=3.0,Purity=1.0)
# Creating Left Child Node With 24 Examples, and Right Node with 3 Examples
# Creating Left Child Node With 3 Examples, and Right Node with 21 Examples
# C(posterior=[],class=3.0,Purity=1.0)
# C(posterior=[],class=1.0,Purity=0.571428571429)
# C(posterior=[],class=3.0,Purity=1.0)
# Creating Left Child Node With 89 Examples, and Right Node with 915 Examples
# Creating Left Child Node With 43 Examples, and Right Node with 46 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 42 Examples
# C(posterior=[],class=1.0,Purity=1.0)
# C(posterior=[],class=4.0,Purity=0.952380952381)
# C(posterior=[],class=2.0,Purity=0.95652173913)
# Creating Left Child Node With 814 Examples, and Right Node with 101 Examples
# Creating Left Child Node With 403 Examples, and Right Node with 411 Examples
# C(posterior=[],class=4.0,Purity=0.995037220844)
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 64 Examples, and Right Node with 37 Examples
# Creating Left Child Node With 34 Examples, and Right Node with 30 Examples
# C(posterior=[],class=4.0,Purity=1.0)
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 14 Examples, and Right Node with 23 Examples
# C(posterior=[],class=4.0,Purity=0.785714285714)
# C(posterior=[],class=4.0,Purity=0.565217391304)
# Creating Left Child Node With 1002 Examples, and Right Node with 998 Examples
# Creating Left Child Node With 993 Examples, and Right Node with 9 Examples
# Creating Left Child Node With 151 Examples, and Right Node with 842 Examples
# Creating Left Child Node With 13 Examples, and Right Node with 138 Examples
# Creating Left Child Node With 7 Examples, and Right Node with 6 Examples
# C(posterior=[],class=1.0,Purity=0.571428571429)
# C(posterior=[],class=1.0,Purity=0.666666666667)
# Creating Left Child Node With 59 Examples, and Right Node with 79 Examples
# C(posterior=[],class=1.0,Purity=1.0)
# C(posterior=[],class=4.0,Purity=1.0)
# Creating Left Child Node With 453 Examples, and Right Node with 389 Examples
# Creating Left Child Node With 160 Examples, and Right Node with 293 Examples
# C(posterior=[],class=1.0,Purity=0.9625)
# C(posterior=[],class=1.0,Purity=0.935153583618)
# C(posterior=[],class=4.0,Purity=1.0)
# Creating Left Child Node With 4 Examples, and Right Node with 5 Examples
# C(posterior=[],class=1.0,Purity=0.75)
# Creating Left Child Node With 2 Examples, and Right Node with 3 Examples
# C(posterior=[],class=2.0,Purity=1.0)
# C(posterior=[],class=4.0,Purity=0.666666666667)
# Creating Left Child Node With 508 Examples, and Right Node with 490 Examples
# C(posterior=[],class=3.0,Purity=0.982283464567)
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 993 Examples, and Right Node with 1007 Examples
# Creating Left Child Node With 495 Examples, and Right Node with 498 Examples
# C(posterior=[],class=1.0,Purity=0.99797979798)
# C(posterior=[],class=3.0,Purity=0.993975903614)
# Creating Left Child Node With 500 Examples, and Right Node with 507 Examples
# C(posterior=[],class=4.0,Purity=0.994)
# C(posterior=[],class=2.0,Purity=0.986193293886)
# Creating Left Child Node With 1006 Examples, and Right Node with 994 Examples
# Creating Left Child Node With 997 Examples, and Right Node with 9 Examples
# Creating Left Child Node With 967 Examples, and Right Node with 30 Examples
# Creating Left Child Node With 516 Examples, and Right Node with 451 Examples
# Creating Left Child Node With 260 Examples, and Right Node with 256 Examples
# C(posterior=[],class=1.0,Purity=0.957692307692)
# C(posterior=[],class=1.0,Purity=0.921875)
# C(posterior=[],class=4.0,Purity=1.0)
# Creating Left Child Node With 26 Examples, and Right Node with 4 Examples
# Creating Left Child Node With 10 Examples, and Right Node with 16 Examples
# C(posterior=[],class=1.0,Purity=1.0)
# C(posterior=[],class=4.0,Purity=1.0)
# C(posterior=[],class=1.0,Purity=0.5)
# Creating Left Child Node With 5 Examples, and Right Node with 4 Examples
# Creating Left Child Node With 4 Examples, and Right Node with 1 Examples
# C(posterior=[],class=3.0,Purity=0.75)
# C(posterior=[],class=1.0,Purity=1.0)
# C(posterior=[],class=2.0,Purity=0.5)
# Creating Left Child Node With 493 Examples, and Right Node with 501 Examples
# C(posterior=[],class=3.0,Purity=0.997971602434)
# C(posterior=[],class=2.0,Purity=0.99001996008)
# Creating Left Child Node With 1000 Examples, and Right Node with 1000 Examples
# Creating Left Child Node With 963 Examples, and Right Node with 37 Examples
# Creating Left Child Node With 837 Examples, and Right Node with 126 Examples
# Creating Left Child Node With 10 Examples, and Right Node with 827 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 9 Examples
# C(posterior=[],class=1.0,Purity=1.0)
# C(posterior=[],class=3.0,Purity=0.777777777778)
# Creating Left Child Node With 423 Examples, and Right Node with 404 Examples
# C(posterior=[],class=1.0,Purity=1.0)
# C(posterior=[],class=3.0,Purity=0.987623762376)
# Creating Left Child Node With 22 Examples, and Right Node with 104 Examples
# Creating Left Child Node With 13 Examples, and Right Node with 9 Examples
# C(posterior=[],class=1.0,Purity=1.0)
# C(posterior=[],class=3.0,Purity=1.0)
# Creating Left Child Node With 39 Examples, and Right Node with 65 Examples
# C(posterior=[],class=1.0,Purity=1.0)
# C(posterior=[],class=3.0,Purity=1.0)
# Creating Left Child Node With 34 Examples, and Right Node with 3 Examples
# Creating Left Child Node With 15 Examples, and Right Node with 19 Examples
# Creating Left Child Node With 12 Examples, and Right Node with 3 Examples
# C(posterior=[],class=1.0,Purity=1.0)
# C(posterior=[],class=1.0,Purity=0.666666666667)
# C(posterior=[],class=3.0,Purity=1.0)
# C(posterior=[],class=1.0,Purity=0.333333333333)
# Creating Left Child Node With 58 Examples, and Right Node with 942 Examples
# Creating Left Child Node With 53 Examples, and Right Node with 5 Examples
# Creating Left Child Node With 7 Examples, and Right Node with 46 Examples
# Creating Left Child Node With 3 Examples, and Right Node with 4 Examples
# C(posterior=[],class=4.0,Purity=1.0)
# C(posterior=[],class=2.0,Purity=0.75)
# Creating Left Child Node With 24 Examples, and Right Node with 22 Examples
# C(posterior=[],class=4.0,Purity=0.916666666667)
# C(posterior=[],class=2.0,Purity=1.0)
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 466 Examples, and Right Node with 476 Examples
# C(posterior=[],class=4.0,Purity=1.0)
# C(posterior=[],class=2.0,Purity=0.985294117647)
# Creating Left Child Node With 1022 Examples, and Right Node with 978 Examples
# Creating Left Child Node With 507 Examples, and Right Node with 515 Examples
# C(posterior=[],class=1.0,Purity=0.980276134122)
# C(posterior=[],class=4.0,Purity=0.968932038835)
# Creating Left Child Node With 14 Examples, and Right Node with 964 Examples
# Creating Left Child Node With 8 Examples, and Right Node with 6 Examples
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 2 Examples, and Right Node with 4 Examples
# C(posterior=[],class=3.0,Purity=1.0)
# C(posterior=[],class=2.0,Purity=0.75)
# Creating Left Child Node With 487 Examples, and Right Node with 477 Examples
# C(posterior=[],class=3.0,Purity=1.0)
# C(posterior=[],class=2.0,Purity=0.997903563941)
# Creating Left Child Node With 1003 Examples, and Right Node with 997 Examples
# Creating Left Child Node With 471 Examples, and Right Node with 532 Examples
# C(posterior=[],class=1.0,Purity=0.993630573248)
# Creating Left Child Node With 34 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 27 Examples, and Right Node with 7 Examples
# C(posterior=[],class=1.0,Purity=1.0)
# Creating Left Child Node With 4 Examples, and Right Node with 3 Examples
# C(posterior=[],class=1.0,Purity=0.5)
# C(posterior=[],class=3.0,Purity=0.666666666667)
# C(posterior=[],class=3.0,Purity=0.993975903614)
# Creating Left Child Node With 26 Examples, and Right Node with 971 Examples
# Creating Left Child Node With 5 Examples, and Right Node with 21 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 4 Examples
# C(posterior=[],class=2.0,Purity=1.0)
# C(posterior=[],class=4.0,Purity=0.75)
# Creating Left Child Node With 12 Examples, and Right Node with 9 Examples
# Creating Left Child Node With 5 Examples, and Right Node with 7 Examples
# C(posterior=[],class=4.0,Purity=0.6)
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 3 Examples, and Right Node with 6 Examples
# C(posterior=[],class=4.0,Purity=0.666666666667)
# C(posterior=[],class=2.0,Purity=0.666666666667)
# Creating Left Child Node With 485 Examples, and Right Node with 486 Examples
# C(posterior=[],class=4.0,Purity=1.0)
# C(posterior=[],class=2.0,Purity=0.995884773663)
# Creating Left Child Node With 1000 Examples, and Right Node with 1000 Examples
# Creating Left Child Node With 499 Examples, and Right Node with 501 Examples
# C(posterior=[],class=1.0,Purity=0.993987975952)
# C(posterior=[],class=3.0,Purity=0.994011976048)
# Creating Left Child Node With 8 Examples, and Right Node with 992 Examples
# Creating Left Child Node With 4 Examples, and Right Node with 4 Examples
# C(posterior=[],class=4.0,Purity=1.0)
# C(posterior=[],class=2.0,Purity=0.75)
# Creating Left Child Node With 49 Examples, and Right Node with 943 Examples
# Creating Left Child Node With 45 Examples, and Right Node with 4 Examples
# Creating Left Child Node With 12 Examples, and Right Node with 33 Examples
# C(posterior=[],class=2.0,Purity=0.583333333333)
# C(posterior=[],class=4.0,Purity=0.545454545455)
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 846 Examples, and Right Node with 97 Examples
# Creating Left Child Node With 415 Examples, and Right Node with 431 Examples
# C(posterior=[],class=4.0,Purity=1.0)
# C(posterior=[],class=2.0,Purity=0.99535962877)
# Creating Left Child Node With 95 Examples, and Right Node with 2 Examples
# C(posterior=[],class=4.0,Purity=0.568421052632)
# C(posterior=[],class=4.0,Purity=1.0)
# Creating Left Child Node With 1004 Examples, and Right Node with 996 Examples
# Creating Left Child Node With 502 Examples, and Right Node with 502 Examples
# C(posterior=[],class=1.0,Purity=0.990039840637)
# C(posterior=[],class=4.0,Purity=0.990039840637)
# Creating Left Child Node With 590 Examples, and Right Node with 406 Examples
# Creating Left Child Node With 13 Examples, and Right Node with 577 Examples
# Creating Left Child Node With 5 Examples, and Right Node with 8 Examples
# Creating Left Child Node With 3 Examples, and Right Node with 2 Examples
# C(posterior=[],class=3.0,Purity=0.666666666667)
# C(posterior=[],class=3.0,Purity=1.0)
# Creating Left Child Node With 5 Examples, and Right Node with 3 Examples
# C(posterior=[],class=3.0,Purity=1.0)
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 134 Examples, and Right Node with 443 Examples
# Creating Left Child Node With 114 Examples, and Right Node with 20 Examples
# C(posterior=[],class=3.0,Purity=1.0)
# C(posterior=[],class=2.0,Purity=0.85)
# Creating Left Child Node With 440 Examples, and Right Node with 3 Examples
# C(posterior=[],class=3.0,Purity=0.840909090909)
# C(posterior=[],class=3.0,Purity=0.666666666667)
# C(posterior=[],class=2.0,Purity=1.0)

# %%
len(rfc.trees)
# Out:
# 10

# %%
# Training Confusion Matrix...
Yp=rfc.predict(X)
print Y.shape, len(Yp)
t.print_confusion_matrix(Yp,Y)
# Out:
# (2000L, 1L) 2000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        497    0    1    2   500
# 2.0          0  500    0    0   500
# 3.0          1    2  497    0   500
# 4.0          2    2    0  496   500
# All        500  504  498  498  2000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Y ==  np.array(Yp)) / float(Y.shape[0])

assert_greater_equal(acc, 0.78)

# %%
#It might take time, a little longer than the desired
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('training-boundary-rf-raa-10trees.svg',format='svg')

# %%
#Testing Confusion Matrix...
Ypt=rfc.predict(Xt)
print Ypt.shape, len(Ypt)
t.print_confusion_matrix(Ypt,Yt)
# Out:
# (1000L, 1L) 1000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        250    0    0    0   250
# 2.0          0  250    0    0   250
# 3.0          1    1  248    0   250
# 4.0          1    2    0  247   250
# All        252  253  248  247  1000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Yt.flatten() ==  np.array(Ypt)) / float(Yt.shape[0]) 

assert_greater_equal(acc, 0.78)

# %%
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('testing-boundary-rf-raa-10trees.svg',format='svg')

# %%
#plt.style.use('ggplot')
#matplotlib.rcParams['figure.figsize'] = (14.0, 8.0)
t.plot_points_range(rfc,X,Y,10000)
# Out:
# (10000L, 2L)
# [1.0, 2.0, 3.0, 4.0]
# tools.py:844: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(True)

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
ntrees=rfc.ntrees
nrows=ntrees/2
ncols=2
i=1
plt.subplots(nrows,ncols,figsize=(16,20))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    t.plot_decision_regions(X,np.squeeze(Y),clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# #### What Can You conclude

# %% [markdown]
# ## Lets Run on Nonlinear Data, The Spherical Examples...

# %%
#Get Training Data from a spherical distribution and ...
X,Y=t.get_spherical_data(N=10000)

# %%
#Get Test Data 
Xtest,Ytest=t.get_spherical_data(N=5000)

# %%
rfc=rf.RandomForest(weaklearner='Axis-Aligned-Random',usebagging=False)
rfc.train(X,Y)
# Out:
# Creating Left Child Node With 23343 Examples, and Right Node with 6657 Examples
# Creating Left Child Node With 15754 Examples, and Right Node with 7589 Examples
# Creating Left Child Node With 3555 Examples, and Right Node with 12199 Examples
# Creating Left Child Node With 1671 Examples, and Right Node with 1884 Examples
# Creating Left Child Node With 285 Examples, and Right Node with 1386 Examples
# C(posterior=[],class=0,Purity=0.99298245614)
# C(posterior=[],class=2,Purity=0.994227994228)
# Creating Left Child Node With 961 Examples, and Right Node with 923 Examples
# C(posterior=[],class=2,Purity=0.701352757544)
# C(posterior=[],class=2,Purity=0.632719393283)
# Creating Left Child Node With 5326 Examples, and Right Node with 6873 Examples
# Creating Left Child Node With 3275 Examples, and Right Node with 2051 Examples
# C(posterior=[],class=2,Purity=0.635419847328)
# C(posterior=[],class=2,Purity=0.795709410044)
# Creating Left Child Node With 3680 Examples, and Right Node with 3193 Examples
# C(posterior=[],class=1,Purity=0.998369565217)
# C(posterior=[],class=0,Purity=0.55433761353)
# Creating Left Child Node With 6460 Examples, and Right Node with 1129 Examples
# Creating Left Child Node With 3856 Examples, and Right Node with 2604 Examples
# Creating Left Child Node With 1046 Examples, and Right Node with 2810 Examples
# C(posterior=[],class=2,Purity=0.665391969407)
# C(posterior=[],class=0,Purity=0.998576512456)
# C(posterior=[],class=0,Purity=0.977342549923)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 2019 Examples, and Right Node with 4638 Examples
# Creating Left Child Node With 885 Examples, and Right Node with 1134 Examples
# Creating Left Child Node With 593 Examples, and Right Node with 292 Examples
# Creating Left Child Node With 299 Examples, and Right Node with 294 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 208 Examples, and Right Node with 84 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=2,Purity=0.990299823633)
# C(posterior=[],class=1,Purity=0.997843898232)
# Creating Left Child Node With 21260 Examples, and Right Node with 8740 Examples
# Creating Left Child Node With 8664 Examples, and Right Node with 12596 Examples
# Creating Left Child Node With 3232 Examples, and Right Node with 5432 Examples
# Creating Left Child Node With 2662 Examples, and Right Node with 570 Examples
# C(posterior=[],class=0,Purity=0.996243425995)
# Creating Left Child Node With 39 Examples, and Right Node with 531 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=2,Purity=0.990427098675)
# Creating Left Child Node With 2679 Examples, and Right Node with 9917 Examples
# C(posterior=[],class=2,Purity=0.99962672639)
# Creating Left Child Node With 6795 Examples, and Right Node with 3122 Examples
# Creating Left Child Node With 3321 Examples, and Right Node with 3474 Examples
# C(posterior=[],class=1,Purity=0.582655826558)
# C(posterior=[],class=0,Purity=0.590961427749)
# C(posterior=[],class=1,Purity=0.966367713004)
# Creating Left Child Node With 6115 Examples, and Right Node with 2625 Examples
# Creating Left Child Node With 1719 Examples, and Right Node with 4396 Examples
# C(posterior=[],class=0,Purity=0.979057591623)
# Creating Left Child Node With 3451 Examples, and Right Node with 945 Examples
# C(posterior=[],class=0,Purity=0.98290350623)
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=1,Purity=0.997714285714)
# Creating Left Child Node With 22155 Examples, and Right Node with 7845 Examples
# Creating Left Child Node With 4186 Examples, and Right Node with 17969 Examples
# Creating Left Child Node With 3488 Examples, and Right Node with 698 Examples
# C(posterior=[],class=0,Purity=0.997133027523)
# Creating Left Child Node With 237 Examples, and Right Node with 461 Examples
# Creating Left Child Node With 127 Examples, and Right Node with 110 Examples
# C(posterior=[],class=0,Purity=0.92125984252)
# C(posterior=[],class=0,Purity=0.745454545455)
# Creating Left Child Node With 262 Examples, and Right Node with 199 Examples
# C(posterior=[],class=2,Purity=0.923664122137)
# C(posterior=[],class=0,Purity=0.979899497487)
# Creating Left Child Node With 7135 Examples, and Right Node with 10834 Examples
# Creating Left Child Node With 3332 Examples, and Right Node with 3803 Examples
# C(posterior=[],class=2,Purity=0.978691476591)
# Creating Left Child Node With 1785 Examples, and Right Node with 2018 Examples
# C(posterior=[],class=1,Purity=0.873949579832)
# C(posterior=[],class=1,Purity=0.704658077304)
# Creating Left Child Node With 6758 Examples, and Right Node with 4076 Examples
# Creating Left Child Node With 5588 Examples, and Right Node with 1170 Examples
# C(posterior=[],class=2,Purity=0.561560486757)
# C(posterior=[],class=2,Purity=0.490598290598)
# Creating Left Child Node With 3444 Examples, and Right Node with 632 Examples
# C(posterior=[],class=0,Purity=0.91724738676)
# C(posterior=[],class=0,Purity=0.800632911392)
# Creating Left Child Node With 7345 Examples, and Right Node with 500 Examples
# Creating Left Child Node With 1453 Examples, and Right Node with 5892 Examples
# C(posterior=[],class=2,Purity=0.998623537509)
# C(posterior=[],class=1,Purity=0.986591989138)
# Creating Left Child Node With 185 Examples, and Right Node with 315 Examples
# Creating Left Child Node With 135 Examples, and Right Node with 50 Examples
# Creating Left Child Node With 22 Examples, and Right Node with 113 Examples
# C(posterior=[],class=2,Purity=0.681818181818)
# C(posterior=[],class=2,Purity=0.840707964602)
# C(posterior=[],class=2,Purity=0.96)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 21727 Examples, and Right Node with 8273 Examples
# Creating Left Child Node With 5390 Examples, and Right Node with 16337 Examples
# Creating Left Child Node With 3846 Examples, and Right Node with 1544 Examples
# Creating Left Child Node With 2655 Examples, and Right Node with 1191 Examples
# Creating Left Child Node With 296 Examples, and Right Node with 2359 Examples
# C(posterior=[],class=0,Purity=0.993243243243)
# C(posterior=[],class=2,Purity=0.996608732514)
# Creating Left Child Node With 244 Examples, and Right Node with 947 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 594 Examples, and Right Node with 950 Examples
# Creating Left Child Node With 124 Examples, and Right Node with 470 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.925531914894)
# Creating Left Child Node With 318 Examples, and Right Node with 632 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.996835443038)
# Creating Left Child Node With 7811 Examples, and Right Node with 8526 Examples
# Creating Left Child Node With 453 Examples, and Right Node with 7358 Examples
# Creating Left Child Node With 212 Examples, and Right Node with 241 Examples
# C(posterior=[],class=2,Purity=0.646226415094)
# C(posterior=[],class=2,Purity=0.55601659751)
# Creating Left Child Node With 2337 Examples, and Right Node with 5021 Examples
# C(posterior=[],class=2,Purity=0.634574240479)
# C(posterior=[],class=1,Purity=0.994025094603)
# Creating Left Child Node With 7561 Examples, and Right Node with 965 Examples
# Creating Left Child Node With 5602 Examples, and Right Node with 1959 Examples
# C(posterior=[],class=2,Purity=0.685112459836)
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=1,Purity=0.99896373057)
# Creating Left Child Node With 6043 Examples, and Right Node with 2230 Examples
# Creating Left Child Node With 4757 Examples, and Right Node with 1286 Examples
# C(posterior=[],class=0,Purity=0.997477401724)
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=1,Purity=0.99730941704)
# Creating Left Child Node With 4270 Examples, and Right Node with 25730 Examples
# Creating Left Child Node With 3166 Examples, and Right Node with 1104 Examples
# Creating Left Child Node With 29 Examples, and Right Node with 3137 Examples
# Creating Left Child Node With 17 Examples, and Right Node with 12 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 10 Examples, and Right Node with 3127 Examples
# Creating Left Child Node With 6 Examples, and Right Node with 4 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 365 Examples, and Right Node with 2762 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.999275887038)
# Creating Left Child Node With 274 Examples, and Right Node with 830 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 17394 Examples, and Right Node with 8336 Examples
# Creating Left Child Node With 6828 Examples, and Right Node with 10566 Examples
# Creating Left Child Node With 3850 Examples, and Right Node with 2978 Examples
# Creating Left Child Node With 1396 Examples, and Right Node with 2454 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.995517522412)
# Creating Left Child Node With 2719 Examples, and Right Node with 259 Examples
# C(posterior=[],class=2,Purity=0.780801765355)
# C(posterior=[],class=0,Purity=0.579150579151)
# Creating Left Child Node With 6254 Examples, and Right Node with 4312 Examples
# Creating Left Child Node With 6027 Examples, and Right Node with 227 Examples
# C(posterior=[],class=1,Purity=0.94956031193)
# C(posterior=[],class=2,Purity=0.986784140969)
# Creating Left Child Node With 1482 Examples, and Right Node with 2830 Examples
# C(posterior=[],class=2,Purity=0.987179487179)
# C(posterior=[],class=0,Purity=0.734982332155)
# Creating Left Child Node With 6142 Examples, and Right Node with 2194 Examples
# Creating Left Child Node With 4814 Examples, and Right Node with 1328 Examples
# C(posterior=[],class=0,Purity=0.997091815538)
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 7993 Examples, and Right Node with 22007 Examples
# Creating Left Child Node With 6388 Examples, and Right Node with 1605 Examples
# Creating Left Child Node With 3029 Examples, and Right Node with 3359 Examples
# C(posterior=[],class=0,Purity=0.99669858039)
# C(posterior=[],class=2,Purity=0.981542125633)
# C(posterior=[],class=0,Purity=0.956386292835)
# Creating Left Child Node With 3627 Examples, and Right Node with 18380 Examples
# C(posterior=[],class=2,Purity=0.996691480562)
# Creating Left Child Node With 12946 Examples, and Right Node with 5434 Examples
# Creating Left Child Node With 1967 Examples, and Right Node with 10979 Examples
# Creating Left Child Node With 1137 Examples, and Right Node with 830 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=0,Purity=0.840963855422)
# Creating Left Child Node With 4752 Examples, and Right Node with 6227 Examples
# C(posterior=[],class=1,Purity=0.435816498316)
# C(posterior=[],class=0,Purity=0.61923879878)
# C(posterior=[],class=1,Purity=0.987486198013)
# Creating Left Child Node With 3697 Examples, and Right Node with 26303 Examples
# C(posterior=[],class=0,Purity=0.988909926968)
# Creating Left Child Node With 18531 Examples, and Right Node with 7772 Examples
# Creating Left Child Node With 3659 Examples, and Right Node with 14872 Examples
# C(posterior=[],class=2,Purity=0.985515168079)
# Creating Left Child Node With 10733 Examples, and Right Node with 4139 Examples
# Creating Left Child Node With 2957 Examples, and Right Node with 7776 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=1,Purity=0.760030864198)
# Creating Left Child Node With 3548 Examples, and Right Node with 591 Examples
# C(posterior=[],class=2,Purity=0.660090191657)
# C(posterior=[],class=2,Purity=0.438240270728)
# Creating Left Child Node With 5774 Examples, and Right Node with 1998 Examples
# Creating Left Child Node With 4159 Examples, and Right Node with 1615 Examples
# C(posterior=[],class=0,Purity=0.983890358259)
# C(posterior=[],class=1,Purity=0.991950464396)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 11977 Examples, and Right Node with 18023 Examples
# Creating Left Child Node With 3578 Examples, and Right Node with 8399 Examples
# C(posterior=[],class=0,Purity=0.995248742314)
# Creating Left Child Node With 6197 Examples, and Right Node with 2202 Examples
# Creating Left Child Node With 4648 Examples, and Right Node with 1549 Examples
# C(posterior=[],class=2,Purity=0.975473321859)
# Creating Left Child Node With 689 Examples, and Right Node with 860 Examples
# C(posterior=[],class=0,Purity=0.969521044993)
# C(posterior=[],class=0,Purity=0.867441860465)
# Creating Left Child Node With 2000 Examples, and Right Node with 202 Examples
# Creating Left Child Node With 1086 Examples, and Right Node with 914 Examples
# C(posterior=[],class=2,Purity=0.660220994475)
# C(posterior=[],class=2,Purity=0.647702407002)
# Creating Left Child Node With 46 Examples, and Right Node with 156 Examples
# C(posterior=[],class=2,Purity=0.652173913043)
# C(posterior=[],class=2,Purity=0.512820512821)
# Creating Left Child Node With 2763 Examples, and Right Node with 15260 Examples
# C(posterior=[],class=2,Purity=0.991675714803)
# Creating Left Child Node With 9759 Examples, and Right Node with 5501 Examples
# Creating Left Child Node With 3580 Examples, and Right Node with 6179 Examples
# Creating Left Child Node With 3040 Examples, and Right Node with 540 Examples
# C(posterior=[],class=1,Purity=0.586184210526)
# C(posterior=[],class=0,Purity=0.77037037037)
# Creating Left Child Node With 5917 Examples, and Right Node with 262 Examples
# C(posterior=[],class=0,Purity=0.65151259084)
# C(posterior=[],class=1,Purity=0.912213740458)
# C(posterior=[],class=1,Purity=0.991637884021)
# Creating Left Child Node With 4849 Examples, and Right Node with 25151 Examples
# Creating Left Child Node With 3547 Examples, and Right Node with 1302 Examples
# C(posterior=[],class=0,Purity=0.996053002537)
# Creating Left Child Node With 804 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 45 Examples, and Right Node with 759 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 14 Examples, and Right Node with 484 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=0,Purity=0.97520661157)
# Creating Left Child Node With 19198 Examples, and Right Node with 5953 Examples
# Creating Left Child Node With 3981 Examples, and Right Node with 15217 Examples
# C(posterior=[],class=2,Purity=0.993971363979)
# Creating Left Child Node With 2856 Examples, and Right Node with 12361 Examples
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 4178 Examples, and Right Node with 8183 Examples
# C(posterior=[],class=2,Purity=0.507419818095)
# C(posterior=[],class=1,Purity=0.595991690089)
# Creating Left Child Node With 3583 Examples, and Right Node with 2370 Examples
# Creating Left Child Node With 2769 Examples, and Right Node with 814 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=1,Purity=0.994936708861)
# Creating Left Child Node With 5783 Examples, and Right Node with 24217 Examples
# Creating Left Child Node With 1867 Examples, and Right Node with 3916 Examples
# Creating Left Child Node With 540 Examples, and Right Node with 1327 Examples
# Creating Left Child Node With 265 Examples, and Right Node with 275 Examples
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 247 Examples, and Right Node with 28 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 619 Examples, and Right Node with 708 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=2,Purity=0.988253319714)
# Creating Left Child Node With 14989 Examples, and Right Node with 9228 Examples
# Creating Left Child Node With 5203 Examples, and Right Node with 9786 Examples
# Creating Left Child Node With 3321 Examples, and Right Node with 1882 Examples
# Creating Left Child Node With 1153 Examples, and Right Node with 2168 Examples
# C(posterior=[],class=0,Purity=0.999132697311)
# C(posterior=[],class=2,Purity=0.998616236162)
# Creating Left Child Node With 333 Examples, and Right Node with 1549 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.997417688832)
# Creating Left Child Node With 6791 Examples, and Right Node with 2995 Examples
# Creating Left Child Node With 3039 Examples, and Right Node with 3752 Examples
# C(posterior=[],class=1,Purity=0.99967094439)
# C(posterior=[],class=0,Purity=0.537313432836)
# C(posterior=[],class=1,Purity=0.983639398998)
# Creating Left Child Node With 6511 Examples, and Right Node with 2717 Examples
# Creating Left Child Node With 5544 Examples, and Right Node with 967 Examples
# C(posterior=[],class=0,Purity=0.962301587302)
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=1,Purity=0.996687523003)

# %%
#Training Confusion Matrix
Yp=rfc.predict(X)
print Y.shape, len(Yp)
t.print_confusion_matrix(Yp,Y)
# Out:
# (30000L,) 30000
# Predicted     0      1     2    All
# Actual
# 0          9924     55    21  10000
# 1            11   9986     3  10000
# 2            32    529  9439  10000
# All        9967  10570  9463  30000

# %%
#Testing Confusion Matrix
Ypt=rfc.predict(Xtest)
print Y.shape, len(Ypt)
t.print_confusion_matrix(Ypt,Ytest)
# Out:
# (30000L,) 15000
# Predicted     0     1     2    All
# Actual
# 0          4967    27     6   5000
# 1             4  4995     1   5000
# 2            16   270  4714   5000
# All        4987  5292  4721  15000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Y.flatten() ==  np.array(Yp)) / float(Y.shape[0]) 

assert_greater_equal(acc, 0.78)

# %%
t.plot_points_range(rfc,X,Y)
# Out:
# (10000L, 2L)
# [0, 1, 2]

# %%
t.plot_decision_regions(X,Y,rfc)

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
ntrees=rfc.ntrees
nrows=ntrees/2
ncols=2
i=1
plt.subplots(nrows,ncols,figsize=(16,20))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    t.plot_decision_regions(X,Y,clf=tree);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# ## TODO: Find Optimal Number of Trees for this data set, using cross validation...
