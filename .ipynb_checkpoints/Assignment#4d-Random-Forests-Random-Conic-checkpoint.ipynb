# %% [markdown]
# # Assignment No 4d
# ###### *Sibt ul Hussain*
# ----
# ## Goal
#
# Your goal in this assigment is to implement and test different variants of Random Forests. For this part you will be implemented randomized version of Conic weak learner based Random Forest.
#
# **Note** Please note that you are allowed to use only those libraries which we have discussed in the class, i.e. numpy, scipy, pandas.
#
# ## Submission Instructions
# You are required to submit the original notebook file on the Slate (with .ipynb extension), with complete set of outputs. Students failing to do so will get zero marks.
#
# *Please read each step carefully and understand it fully before proceeding with code writing*
#
# ## Plagiarism
# Any form of plagiarism will not be tolerated and result in 0 marks.

# %%
# %pylab inline
import scipy.stats
from collections import defaultdict  # default dictionary 
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)
# %load_ext autoreload 
# %autoreload 2
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import tools as t # set of tools for plotting, data splitting, etc..
import time

# %%
# Create some dummy data for testing
np.random.seed(seed=99)

# %% [markdown]
# ## Let's cook some data up for a multi-class classification problem...

# %%
#generate training and testing set...by sampling from mutli-variate Gaussian
cp=5
nclasses=2
mean1 = [-cp,-cp]
mean2 = [cp,cp]
mean3 = [cp,-cp]
mean4 = [-cp,cp]
cov = [[3.0,0.0],[0.0,3.0]] 

#create some points for the training set...
nexamples=2000
x1 = np.random.multivariate_normal(mean1,cov,nexamples/4)
x2 = np.random.multivariate_normal(mean2,cov,nexamples/4)
x3 = np.random.multivariate_normal(mean3,cov,nexamples/4)
x4 = np.random.multivariate_normal(mean4,cov,nexamples/4)

X=np.vstack((x1,x2,x3,x4))
Y=np.vstack((1*np.ones((nexamples/4,1)),2*np.ones((nexamples/4,1)),3*np.ones((nexamples/4,1)),4*np.ones((nexamples/4,1))))


plt.scatter(x1[:,0],x1[:,1], c='r', s=100)
plt.scatter(x2[:,0],x2[:,1], c='g', s=100)            
plt.scatter(x3[:,0],x3[:,1], c='b', s=100)
plt.scatter(x4[:,0],x4[:,1], c='y', s=100)            



plt.title("Multi-class Classification")
plt.xlabel("feature $x_1$")
plt.ylabel("feature $x_2$")
plt.legend(['r','g','b','y'])
fig_ml_in_10 = plt.gcf()
plt.savefig('multi-linear-class.svg',format='svg')
#create some points for the training set..

ntexamples=1000
x1 = np.random.multivariate_normal(mean1,cov,ntexamples/4)
x2 = np.random.multivariate_normal(mean2,cov,ntexamples/4)
x3 = np.random.multivariate_normal(mean3,cov,ntexamples/4)
x4 = np.random.multivariate_normal(mean4,cov,ntexamples/4)

Xt=np.vstack((x1,x2,x3,x4))
Yt=np.vstack((1*np.ones((ntexamples/4,1)),2*np.ones((ntexamples/4,1)),3*np.ones((ntexamples/4,1)),4*np.ones((ntexamples/4,1))))

# %%
import randomForest as rf

# %%
rfc=rf.RandomForest(weaklearner='Conic')

# %%
print X.shape, Y.shape
# Out:
# (2000L, 2L) (2000L, 1L)

# %%
rfc.train(X,Y)
# Out:
# Creating Left Child Node With 1040 Examples, and Right Node with 960 Examples
# Creating Left Child Node With 479 Examples, and Right Node with 561 Examples
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 522 Examples, and Right Node with 39 Examples
# C(posterior=[],class=3.0,Purity=0.955938697318)
# Creating Left Child Node With 11 Examples, and Right Node with 28 Examples
# Creating Left Child Node With 3 Examples, and Right Node with 8 Examples
# C(posterior=[],class=2.0,Purity=0.666666666667)
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 24 Examples, and Right Node with 4 Examples
# C(posterior=[],class=4.0,Purity=0.625)
# C(posterior=[],class=4.0,Purity=0.5)
# Creating Left Child Node With 451 Examples, and Right Node with 509 Examples
# C(posterior=[],class=4.0,Purity=0.991130820399)
# Creating Left Child Node With 475 Examples, and Right Node with 34 Examples
# C(posterior=[],class=1.0,Purity=0.997894736842)
# Creating Left Child Node With 19 Examples, and Right Node with 15 Examples
# C(posterior=[],class=4.0,Purity=1.0)
# Creating Left Child Node With 13 Examples, and Right Node with 2 Examples
# C(posterior=[],class=4.0,Purity=0.923076923077)
# C(posterior=[],class=1.0,Purity=1.0)
# Creating Left Child Node With 996 Examples, and Right Node with 1004 Examples
# Creating Left Child Node With 32 Examples, and Right Node with 964 Examples
# Creating Left Child Node With 21 Examples, and Right Node with 11 Examples
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 8 Examples, and Right Node with 3 Examples
# C(posterior=[],class=3.0,Purity=1.0)
# C(posterior=[],class=3.0,Purity=0.666666666667)
# Creating Left Child Node With 484 Examples, and Right Node with 480 Examples
# C(posterior=[],class=3.0,Purity=0.995867768595)
# C(posterior=[],class=2.0,Purity=0.9875)
# Creating Left Child Node With 504 Examples, and Right Node with 500 Examples
# C(posterior=[],class=4.0,Purity=0.986111111111)
# C(posterior=[],class=1.0,Purity=0.99)
# Creating Left Child Node With 999 Examples, and Right Node with 1001 Examples
# Creating Left Child Node With 493 Examples, and Right Node with 506 Examples
# C(posterior=[],class=1.0,Purity=0.995943204868)
# C(posterior=[],class=3.0,Purity=0.986166007905)
# Creating Left Child Node With 962 Examples, and Right Node with 39 Examples
# Creating Left Child Node With 437 Examples, and Right Node with 525 Examples
# C(posterior=[],class=4.0,Purity=1.0)
# Creating Left Child Node With 70 Examples, and Right Node with 455 Examples
# Creating Left Child Node With 47 Examples, and Right Node with 23 Examples
# C(posterior=[],class=4.0,Purity=0.957446808511)
# C(posterior=[],class=2.0,Purity=1.0)
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 18 Examples, and Right Node with 21 Examples
# Creating Left Child Node With 8 Examples, and Right Node with 10 Examples
# C(posterior=[],class=4.0,Purity=1.0)
# Creating Left Child Node With 4 Examples, and Right Node with 6 Examples
# C(posterior=[],class=4.0,Purity=0.75)
# C(posterior=[],class=4.0,Purity=0.833333333333)
# C(posterior=[],class=2.0,Purity=0.952380952381)
# Creating Left Child Node With 999 Examples, and Right Node with 1001 Examples
# Creating Left Child Node With 518 Examples, and Right Node with 481 Examples
# C(posterior=[],class=4.0,Purity=0.959459459459)
# C(posterior=[],class=2.0,Purity=0.997920997921)
# Creating Left Child Node With 455 Examples, and Right Node with 546 Examples
# C(posterior=[],class=3.0,Purity=0.995604395604)
# Creating Left Child Node With 497 Examples, and Right Node with 49 Examples
# C(posterior=[],class=1.0,Purity=0.987927565392)
# Creating Left Child Node With 44 Examples, and Right Node with 5 Examples
# C(posterior=[],class=3.0,Purity=0.977272727273)
# C(posterior=[],class=1.0,Purity=1.0)
# Creating Left Child Node With 555 Examples, and Right Node with 1445 Examples
# Creating Left Child Node With 83 Examples, and Right Node with 472 Examples
# Creating Left Child Node With 64 Examples, and Right Node with 19 Examples
# C(posterior=[],class=4.0,Purity=0.96875)
# Creating Left Child Node With 16 Examples, and Right Node with 3 Examples
# Creating Left Child Node With 6 Examples, and Right Node with 10 Examples
# C(posterior=[],class=1.0,Purity=0.833333333333)
# C(posterior=[],class=4.0,Purity=0.6)
# C(posterior=[],class=1.0,Purity=1.0)
# C(posterior=[],class=1.0,Purity=0.991525423729)
# Creating Left Child Node With 822 Examples, and Right Node with 623 Examples
# Creating Left Child Node With 343 Examples, and Right Node with 479 Examples
# C(posterior=[],class=4.0,Purity=0.98833819242)
# C(posterior=[],class=2.0,Purity=0.997912317328)
# Creating Left Child Node With 100 Examples, and Right Node with 523 Examples
# Creating Left Child Node With 81 Examples, and Right Node with 19 Examples
# C(posterior=[],class=4.0,Purity=0.975308641975)
# Creating Left Child Node With 14 Examples, and Right Node with 5 Examples
# C(posterior=[],class=4.0,Purity=0.571428571429)
# C(posterior=[],class=1.0,Purity=1.0)
# C(posterior=[],class=3.0,Purity=0.956022944551)
# Creating Left Child Node With 994 Examples, and Right Node with 1006 Examples
# Creating Left Child Node With 484 Examples, and Right Node with 510 Examples
# C(posterior=[],class=1.0,Purity=0.997933884298)
# C(posterior=[],class=3.0,Purity=0.972549019608)
# Creating Left Child Node With 29 Examples, and Right Node with 977 Examples
# Creating Left Child Node With 13 Examples, and Right Node with 16 Examples
# Creating Left Child Node With 12 Examples, and Right Node with 1 Examples
# Creating Left Child Node With 10 Examples, and Right Node with 2 Examples
# C(posterior=[],class=4.0,Purity=0.8)
# C(posterior=[],class=1.0,Purity=0.5)
# C(posterior=[],class=4.0,Purity=1.0)
# Creating Left Child Node With 13 Examples, and Right Node with 3 Examples
# Creating Left Child Node With 12 Examples, and Right Node with 1 Examples
# C(posterior=[],class=2.0,Purity=0.916666666667)
# C(posterior=[],class=2.0,Purity=1.0)
# C(posterior=[],class=3.0,Purity=1.0)
# Creating Left Child Node With 533 Examples, and Right Node with 444 Examples
# Creating Left Child Node With 48 Examples, and Right Node with 485 Examples
# Creating Left Child Node With 47 Examples, and Right Node with 1 Examples
# C(posterior=[],class=4.0,Purity=0.957446808511)
# C(posterior=[],class=2.0,Purity=1.0)
# C(posterior=[],class=2.0,Purity=1.0)
# C(posterior=[],class=4.0,Purity=1.0)
# Creating Left Child Node With 902 Examples, and Right Node with 1098 Examples
# Creating Left Child Node With 437 Examples, and Right Node with 465 Examples
# C(posterior=[],class=2.0,Purity=0.997711670481)
# C(posterior=[],class=3.0,Purity=0.984946236559)
# Creating Left Child Node With 987 Examples, and Right Node with 111 Examples
# Creating Left Child Node With 692 Examples, and Right Node with 295 Examples
# Creating Left Child Node With 315 Examples, and Right Node with 377 Examples
# C(posterior=[],class=1.0,Purity=0.987301587302)
# Creating Left Child Node With 269 Examples, and Right Node with 108 Examples
# C(posterior=[],class=4.0,Purity=1.0)
# C(posterior=[],class=4.0,Purity=0.638888888889)
# Creating Left Child Node With 103 Examples, and Right Node with 192 Examples
# C(posterior=[],class=1.0,Purity=1.0)
# Creating Left Child Node With 49 Examples, and Right Node with 143 Examples
# C(posterior=[],class=4.0,Purity=0.816326530612)
# C(posterior=[],class=4.0,Purity=0.783216783217)
# Creating Left Child Node With 60 Examples, and Right Node with 51 Examples
# Creating Left Child Node With 23 Examples, and Right Node with 37 Examples
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 25 Examples, and Right Node with 12 Examples
# C(posterior=[],class=2.0,Purity=0.8)
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 48 Examples, and Right Node with 3 Examples
# Creating Left Child Node With 46 Examples, and Right Node with 2 Examples
# C(posterior=[],class=3.0,Purity=0.891304347826)
# C(posterior=[],class=2.0,Purity=1.0)
# C(posterior=[],class=1.0,Purity=0.666666666667)
# Creating Left Child Node With 1515 Examples, and Right Node with 485 Examples
# Creating Left Child Node With 991 Examples, and Right Node with 524 Examples
# Creating Left Child Node With 506 Examples, and Right Node with 485 Examples
# C(posterior=[],class=3.0,Purity=0.98023715415)
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 467 Examples, and Right Node with 57 Examples
# C(posterior=[],class=1.0,Purity=1.0)
# Creating Left Child Node With 29 Examples, and Right Node with 28 Examples
# Creating Left Child Node With 23 Examples, and Right Node with 6 Examples
# C(posterior=[],class=4.0,Purity=0.782608695652)
# C(posterior=[],class=3.0,Purity=0.5)
# Creating Left Child Node With 25 Examples, and Right Node with 3 Examples
# C(posterior=[],class=1.0,Purity=0.96)
# C(posterior=[],class=1.0,Purity=0.666666666667)
# C(posterior=[],class=4.0,Purity=0.989690721649)
# Creating Left Child Node With 1414 Examples, and Right Node with 586 Examples
# Creating Left Child Node With 511 Examples, and Right Node with 903 Examples
# C(posterior=[],class=1.0,Purity=0.970645792564)
# Creating Left Child Node With 411 Examples, and Right Node with 492 Examples
# C(posterior=[],class=4.0,Purity=0.978102189781)
# C(posterior=[],class=3.0,Purity=0.991869918699)
# Creating Left Child Node With 507 Examples, and Right Node with 79 Examples
# C(posterior=[],class=2.0,Purity=0.98224852071)
# C(posterior=[],class=4.0,Purity=0.987341772152)
# Creating Left Child Node With 999 Examples, and Right Node with 1001 Examples
# Creating Left Child Node With 496 Examples, and Right Node with 503 Examples
# C(posterior=[],class=2.0,Purity=0.997983870968)
# C(posterior=[],class=4.0,Purity=0.988071570577)
# Creating Left Child Node With 491 Examples, and Right Node with 510 Examples
# C(posterior=[],class=3.0,Purity=0.997963340122)
# C(posterior=[],class=1.0,Purity=0.976470588235)

# %%
len(rfc.trees)
# Out:
# 10

# %%
# %pdb
# Training Confusion Matrix...
Yp=rfc.predict(X)
print Y.shape, len(Yp)
t.print_confusion_matrix(Yp,Y)
# Out:
# Automatic pdb calling has been turned ON
# (2000L, 1L) 2000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        495    0    3    2   500
# 2.0          0  496    1    3   500
# 3.0          0    1  499    0   500
# 4.0          2    0    0  498   500
# All        497  497  503  503  2000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Y ==  np.array(Yp)) / float(Y.shape[0])

assert_greater_equal(acc, 0.78)

# %%
print acc
# Out:
# 0.994

# %%
#It might take time, a little longer than the desired
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('training-boundary-rf-rlinear-10trees.svg',format='svg')

# %%
#Testing Confusion Matrix...
Ypt=rfc.predict(Xt)
print Y.shape, len(Ypt)
t.print_confusion_matrix(Ypt,Yt)
# Out:
# (2000L, 1L) 1000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        249    0    1    0   250
# 2.0          0  248    1    1   250
# 3.0          0    1  249    0   250
# 4.0          1    0    0  249   250
# All        250  249  251  250  1000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Yt.flatten() ==  np.array(Ypt)) / float(Yt.shape[0]) 

assert_greater_equal(acc, 0.78)

# %%
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('testing-boundary-rf-raa-10trees.svg',format='svg')

# %%
#plt.style.use('ggplot')
#matplotlib.rcParams['figure.figsize'] = (14.0, 8.0)
import tools as t

# %%
t.plot_points_range(rfc,X,Y,10000)
# Out:
# (10000L, 2L)
# [1.0, 2.0, 3.0, 4.0]
# tools.py:844: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(True)

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
# %pdb
ntrees=rfc.ntrees
nrows=ntrees/2 
ncols=2
i=0
plt.subplots(nrows,ncols,figsize=(16,20))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i+1);
    t.plot_decision_regions(X,np.squeeze(Y),clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i+1))
    i=i+1
plt.tight_layout()
# Out:
# Automatic pdb calling has been turned OFF

# %% [markdown]
# #### What Can You conclude

# %% [markdown]
# ## Lets Run on Nonlinear Data, The Spherical Examples...

# %%
#Get Training Data from a spherical distribution and ...
X,Y=t.get_spherical_data(N=10000)

# %%
print X.shape, Y.shape
# Out:
# (30000L, 2L) (30000L,)

# %%
#Get Test Data 
Xtest,Ytest=t.get_spherical_data(N=5000)

# %%
rfc=rf.RandomForest(weaklearner='Conic',usebagging=False,ntrees=20)
rfc.train(X,Y[:,np.newaxis])
# Out:
# Creating Left Child Node With 18896 Examples, and Right Node with 11104 Examples
# Creating Left Child Node With 16215 Examples, and Right Node with 2681 Examples
# Creating Left Child Node With 10387 Examples, and Right Node with 5828 Examples
# Creating Left Child Node With 8918 Examples, and Right Node with 1469 Examples
# Creating Left Child Node With 3079 Examples, and Right Node with 5839 Examples
# C(posterior=[],class=1,Purity=0.540759987009)
# C(posterior=[],class=2,Purity=0.532454187361)
# Creating Left Child Node With 1212 Examples, and Right Node with 257 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=0,Purity=0.677042801556)
# Creating Left Child Node With 656 Examples, and Right Node with 5172 Examples
# Creating Left Child Node With 41 Examples, and Right Node with 615 Examples
# C(posterior=[],class=0,Purity=0.975609756098)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 4400 Examples, and Right Node with 772 Examples
# C(posterior=[],class=0,Purity=0.960681818182)
# C(posterior=[],class=1,Purity=0.634715025907)
# C(posterior=[],class=1,Purity=0.996270048489)
# Creating Left Child Node With 6399 Examples, and Right Node with 4705 Examples
# Creating Left Child Node With 406 Examples, and Right Node with 5993 Examples
# Creating Left Child Node With 84 Examples, and Right Node with 322 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 171 Examples, and Right Node with 5822 Examples
# Creating Left Child Node With 171 Examples, and Right Node with 0 Examples
# C(posterior=[],class=2,Purity=0.760233918129)
# Creating Left Child Node With 5462 Examples, and Right Node with 360 Examples
# C(posterior=[],class=1,Purity=0.686561699011)
# C(posterior=[],class=2,Purity=0.686111111111)
# Creating Left Child Node With 4587 Examples, and Right Node with 118 Examples
# Creating Left Child Node With 168 Examples, and Right Node with 4419 Examples
# Creating Left Child Node With 129 Examples, and Right Node with 39 Examples
# C(posterior=[],class=0,Purity=0.992248062016)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 2305 Examples, and Right Node with 2114 Examples
# C(posterior=[],class=2,Purity=0.99305856833)
# C(posterior=[],class=0,Purity=0.689214758751)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 8775 Examples, and Right Node with 21225 Examples
# Creating Left Child Node With 5405 Examples, and Right Node with 3370 Examples
# Creating Left Child Node With 143 Examples, and Right Node with 5262 Examples
# C(posterior=[],class=1,Purity=0.993006993007)
# C(posterior=[],class=0,Purity=0.960281261878)
# C(posterior=[],class=1,Purity=0.986646884273)
# Creating Left Child Node With 15417 Examples, and Right Node with 5808 Examples
# Creating Left Child Node With 4883 Examples, and Right Node with 10534 Examples
# Creating Left Child Node With 146 Examples, and Right Node with 4737 Examples
# Creating Left Child Node With 72 Examples, and Right Node with 74 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=2,Purity=0.77027027027)
# Creating Left Child Node With 1576 Examples, and Right Node with 3161 Examples
# C(posterior=[],class=0,Purity=0.998730964467)
# C(posterior=[],class=2,Purity=0.999367288833)
# Creating Left Child Node With 2998 Examples, and Right Node with 7536 Examples
# C(posterior=[],class=1,Purity=0.956637758506)
# Creating Left Child Node With 1667 Examples, and Right Node with 5869 Examples
# C(posterior=[],class=2,Purity=0.968206358728)
# C(posterior=[],class=1,Purity=0.584256261714)
# Creating Left Child Node With 2084 Examples, and Right Node with 3724 Examples
# Creating Left Child Node With 1874 Examples, and Right Node with 210 Examples
# Creating Left Child Node With 1048 Examples, and Right Node with 826 Examples
# C(posterior=[],class=0,Purity=0.812977099237)
# C(posterior=[],class=2,Purity=0.73607748184)
# Creating Left Child Node With 133 Examples, and Right Node with 77 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=0,Purity=0.922077922078)
# C(posterior=[],class=2,Purity=0.989258861439)
# Creating Left Child Node With 17642 Examples, and Right Node with 12358 Examples
# Creating Left Child Node With 1780 Examples, and Right Node with 15862 Examples
# Creating Left Child Node With 1615 Examples, and Right Node with 165 Examples
# C(posterior=[],class=1,Purity=0.998142414861)
# Creating Left Child Node With 7 Examples, and Right Node with 158 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=0,Purity=0.981012658228)
# Creating Left Child Node With 11709 Examples, and Right Node with 4153 Examples
# Creating Left Child Node With 3252 Examples, and Right Node with 8457 Examples
# Creating Left Child Node With 238 Examples, and Right Node with 3014 Examples
# C(posterior=[],class=2,Purity=0.974789915966)
# C(posterior=[],class=0,Purity=0.980756469808)
# Creating Left Child Node With 7162 Examples, and Right Node with 1295 Examples
# C(posterior=[],class=2,Purity=0.74853392907)
# C(posterior=[],class=0,Purity=0.985328185328)
# Creating Left Child Node With 1000 Examples, and Right Node with 3153 Examples
# Creating Left Child Node With 495 Examples, and Right Node with 505 Examples
# C(posterior=[],class=1,Purity=0.632323232323)
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=0,Purity=0.969235648589)
# Creating Left Child Node With 7424 Examples, and Right Node with 4934 Examples
# Creating Left Child Node With 4276 Examples, and Right Node with 3148 Examples
# Creating Left Child Node With 735 Examples, and Right Node with 3541 Examples
# Creating Left Child Node With 735 Examples, and Right Node with 0 Examples
# C(posterior=[],class=0,Purity=0.872108843537)
# Creating Left Child Node With 92 Examples, and Right Node with 3449 Examples
# C(posterior=[],class=0,Purity=0.989130434783)
# C(posterior=[],class=2,Purity=0.973325601624)
# Creating Left Child Node With 885 Examples, and Right Node with 2263 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=1,Purity=0.999797324686)
# Creating Left Child Node With 22153 Examples, and Right Node with 7847 Examples
# Creating Left Child Node With 9568 Examples, and Right Node with 12585 Examples
# Creating Left Child Node With 4011 Examples, and Right Node with 5557 Examples
# Creating Left Child Node With 3745 Examples, and Right Node with 266 Examples
# C(posterior=[],class=0,Purity=0.987182910547)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 3939 Examples, and Right Node with 1618 Examples
# C(posterior=[],class=2,Purity=0.999492256918)
# C(posterior=[],class=0,Purity=0.977132262052)
# Creating Left Child Node With 6117 Examples, and Right Node with 6468 Examples
# Creating Left Child Node With 794 Examples, and Right Node with 5323 Examples
# C(posterior=[],class=1,Purity=0.986146095718)
# Creating Left Child Node With 2734 Examples, and Right Node with 2589 Examples
# C(posterior=[],class=0,Purity=0.943672275055)
# C(posterior=[],class=1,Purity=0.998841251448)
# Creating Left Child Node With 864 Examples, and Right Node with 5604 Examples
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 4171 Examples, and Right Node with 1433 Examples
# C(posterior=[],class=0,Purity=0.458882761928)
# C(posterior=[],class=1,Purity=0.990928122819)
# Creating Left Child Node With 2958 Examples, and Right Node with 4889 Examples
# C(posterior=[],class=1,Purity=0.991548343475)
# Creating Left Child Node With 4649 Examples, and Right Node with 240 Examples
# Creating Left Child Node With 1812 Examples, and Right Node with 2837 Examples
# Creating Left Child Node With 183 Examples, and Right Node with 1629 Examples
# C(posterior=[],class=0,Purity=0.994535519126)
# C(posterior=[],class=2,Purity=0.978514426028)
# C(posterior=[],class=2,Purity=0.992597814593)
# Creating Left Child Node With 240 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 240 Examples
# C(posterior=[],class=1,Purity=0.858333333333)
# Creating Left Child Node With 5034 Examples, and Right Node with 24966 Examples
# Creating Left Child Node With 2443 Examples, and Right Node with 2591 Examples
# Creating Left Child Node With 2138 Examples, and Right Node with 305 Examples
# C(posterior=[],class=2,Purity=0.988774555659)
# Creating Left Child Node With 29 Examples, and Right Node with 276 Examples
# C(posterior=[],class=2,Purity=0.965517241379)
# C(posterior=[],class=0,Purity=0.978260869565)
# Creating Left Child Node With 427 Examples, and Right Node with 2164 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=0,Purity=0.997689463956)
# Creating Left Child Node With 6356 Examples, and Right Node with 18610 Examples
# Creating Left Child Node With 1212 Examples, and Right Node with 5144 Examples
# C(posterior=[],class=2,Purity=0.998349834983)
# Creating Left Child Node With 4456 Examples, and Right Node with 688 Examples
# C(posterior=[],class=1,Purity=0.995511669659)
# Creating Left Child Node With 244 Examples, and Right Node with 444 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=2,Purity=0.738738738739)
# Creating Left Child Node With 13138 Examples, and Right Node with 5472 Examples
# Creating Left Child Node With 384 Examples, and Right Node with 12754 Examples
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 9187 Examples, and Right Node with 3567 Examples
# C(posterior=[],class=2,Purity=0.444323500599)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 1436 Examples, and Right Node with 4036 Examples
# Creating Left Child Node With 260 Examples, and Right Node with 1176 Examples
# C(posterior=[],class=1,Purity=0.746153846154)
# C(posterior=[],class=2,Purity=0.551020408163)
# Creating Left Child Node With 2320 Examples, and Right Node with 1716 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=2,Purity=0.621212121212)
# Creating Left Child Node With 22109 Examples, and Right Node with 7891 Examples
# Creating Left Child Node With 7117 Examples, and Right Node with 14992 Examples
# Creating Left Child Node With 3784 Examples, and Right Node with 3333 Examples
# Creating Left Child Node With 871 Examples, and Right Node with 2913 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 1668 Examples, and Right Node with 1665 Examples
# C(posterior=[],class=0,Purity=0.991007194245)
# Creating Left Child Node With 1538 Examples, and Right Node with 127 Examples
# C(posterior=[],class=0,Purity=0.926527958388)
# C(posterior=[],class=2,Purity=0.685039370079)
# Creating Left Child Node With 6230 Examples, and Right Node with 8762 Examples
# Creating Left Child Node With 2032 Examples, and Right Node with 4198 Examples
# Creating Left Child Node With 809 Examples, and Right Node with 1223 Examples
# C(posterior=[],class=2,Purity=0.749072929543)
# C(posterior=[],class=2,Purity=0.999182338512)
# Creating Left Child Node With 2533 Examples, and Right Node with 1665 Examples
# C(posterior=[],class=1,Purity=0.570864587446)
# C(posterior=[],class=1,Purity=0.993993993994)
# Creating Left Child Node With 5720 Examples, and Right Node with 3042 Examples
# C(posterior=[],class=2,Purity=0.972727272727)
# Creating Left Child Node With 1630 Examples, and Right Node with 1412 Examples
# C(posterior=[],class=0,Purity=0.98527607362)
# C(posterior=[],class=0,Purity=0.626062322946)
# Creating Left Child Node With 6195 Examples, and Right Node with 1696 Examples
# Creating Left Child Node With 174 Examples, and Right Node with 6021 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=1,Purity=0.975253280186)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 8368 Examples, and Right Node with 21632 Examples
# Creating Left Child Node With 4633 Examples, and Right Node with 3735 Examples
# C(posterior=[],class=0,Purity=0.990934599611)
# Creating Left Child Node With 2851 Examples, and Right Node with 884 Examples
# C(posterior=[],class=1,Purity=0.987372851631)
# Creating Left Child Node With 668 Examples, and Right Node with 216 Examples
# C(posterior=[],class=1,Purity=0.991017964072)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 10753 Examples, and Right Node with 10879 Examples
# Creating Left Child Node With 6713 Examples, and Right Node with 4040 Examples
# Creating Left Child Node With 2409 Examples, and Right Node with 4304 Examples
# Creating Left Child Node With 1588 Examples, and Right Node with 821 Examples
# C(posterior=[],class=0,Purity=0.936397984887)
# C(posterior=[],class=2,Purity=0.827040194884)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 1370 Examples, and Right Node with 2670 Examples
# Creating Left Child Node With 500 Examples, and Right Node with 870 Examples
# C(posterior=[],class=0,Purity=0.95)
# C(posterior=[],class=0,Purity=0.748275862069)
# C(posterior=[],class=2,Purity=0.980898876404)
# Creating Left Child Node With 2113 Examples, and Right Node with 8766 Examples
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 2688 Examples, and Right Node with 6078 Examples
# Creating Left Child Node With 2289 Examples, and Right Node with 399 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 193 Examples, and Right Node with 5885 Examples
# C(posterior=[],class=0,Purity=0.932642487047)
# C(posterior=[],class=0,Purity=0.367884451997)
# Creating Left Child Node With 22185 Examples, and Right Node with 7815 Examples
# Creating Left Child Node With 13618 Examples, and Right Node with 8567 Examples
# Creating Left Child Node With 7243 Examples, and Right Node with 6375 Examples
# Creating Left Child Node With 2246 Examples, and Right Node with 4997 Examples
# C(posterior=[],class=0,Purity=0.9982190561)
# Creating Left Child Node With 3558 Examples, and Right Node with 1439 Examples
# C(posterior=[],class=1,Purity=0.472175379427)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 778 Examples, and Right Node with 5597 Examples
# C(posterior=[],class=2,Purity=0.974293059126)
# Creating Left Child Node With 5225 Examples, and Right Node with 372 Examples
# C(posterior=[],class=1,Purity=0.628708133971)
# C(posterior=[],class=2,Purity=0.508064516129)
# Creating Left Child Node With 2584 Examples, and Right Node with 5983 Examples
# C(posterior=[],class=2,Purity=0.999226006192)
# Creating Left Child Node With 1149 Examples, and Right Node with 4834 Examples
# C(posterior=[],class=2,Purity=0.991296779809)
# Creating Left Child Node With 1596 Examples, and Right Node with 3238 Examples
# C(posterior=[],class=0,Purity=0.782581453634)
# C(posterior=[],class=0,Purity=0.520691785053)
# Creating Left Child Node With 3346 Examples, and Right Node with 4469 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=0,Purity=0.989706869546)
# Creating Left Child Node With 10618 Examples, and Right Node with 19382 Examples
# Creating Left Child Node With 6959 Examples, and Right Node with 3659 Examples
# Creating Left Child Node With 2050 Examples, and Right Node with 4909 Examples
# Creating Left Child Node With 122 Examples, and Right Node with 1928 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 161 Examples, and Right Node with 4748 Examples
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 151 Examples, and Right Node with 4597 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.953230367631)
# Creating Left Child Node With 3149 Examples, and Right Node with 510 Examples
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 196 Examples, and Right Node with 314 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 11456 Examples, and Right Node with 7926 Examples
# Creating Left Child Node With 1578 Examples, and Right Node with 9878 Examples
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 7754 Examples, and Right Node with 2124 Examples
# Creating Left Child Node With 1729 Examples, and Right Node with 6025 Examples
# C(posterior=[],class=1,Purity=0.922498554078)
# C(posterior=[],class=1,Purity=0.500580912863)
# Creating Left Child Node With 964 Examples, and Right Node with 1160 Examples
# C(posterior=[],class=2,Purity=0.900414937759)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 6024 Examples, and Right Node with 1902 Examples
# Creating Left Child Node With 4146 Examples, and Right Node with 1878 Examples
# Creating Left Child Node With 3234 Examples, and Right Node with 912 Examples
# C(posterior=[],class=1,Purity=0.876623376623)
# C(posterior=[],class=2,Purity=0.665570175439)
# Creating Left Child Node With 1289 Examples, and Right Node with 589 Examples
# C(posterior=[],class=2,Purity=0.753297129558)
# C(posterior=[],class=2,Purity=0.993208828523)
# Creating Left Child Node With 713 Examples, and Right Node with 1189 Examples
# C(posterior=[],class=2,Purity=0.998597475456)
# Creating Left Child Node With 291 Examples, and Right Node with 898 Examples
# C(posterior=[],class=0,Purity=0.570446735395)
# C(posterior=[],class=2,Purity=0.86859688196)
# Creating Left Child Node With 6912 Examples, and Right Node with 23088 Examples
# Creating Left Child Node With 3771 Examples, and Right Node with 3141 Examples
# Creating Left Child Node With 1322 Examples, and Right Node with 2449 Examples
# Creating Left Child Node With 735 Examples, and Right Node with 587 Examples
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 79 Examples, and Right Node with 508 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.986220472441)
# Creating Left Child Node With 1670 Examples, and Right Node with 779 Examples
# C(posterior=[],class=2,Purity=0.950898203593)
# Creating Left Child Node With 588 Examples, and Right Node with 191 Examples
# C(posterior=[],class=0,Purity=0.719387755102)
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=0,Purity=0.99458771092)
# Creating Left Child Node With 17083 Examples, and Right Node with 6005 Examples
# Creating Left Child Node With 9262 Examples, and Right Node with 7821 Examples
# Creating Left Child Node With 6611 Examples, and Right Node with 2651 Examples
# Creating Left Child Node With 1509 Examples, and Right Node with 5102 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=0,Purity=0.783810270482)
# Creating Left Child Node With 1952 Examples, and Right Node with 699 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=1,Purity=0.689556509299)
# Creating Left Child Node With 2450 Examples, and Right Node with 5371 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=1,Purity=0.997579594117)
# Creating Left Child Node With 3336 Examples, and Right Node with 2669 Examples
# Creating Left Child Node With 1964 Examples, and Right Node with 1372 Examples
# Creating Left Child Node With 1681 Examples, and Right Node with 283 Examples
# C(posterior=[],class=2,Purity=0.998215348007)
# C(posterior=[],class=1,Purity=0.752650176678)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 1664 Examples, and Right Node with 1005 Examples
# Creating Left Child Node With 1336 Examples, and Right Node with 328 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=1,Purity=0.942073170732)
# C(posterior=[],class=2,Purity=0.994029850746)
# Creating Left Child Node With 5602 Examples, and Right Node with 24398 Examples
# Creating Left Child Node With 3055 Examples, and Right Node with 2547 Examples
# Creating Left Child Node With 409 Examples, and Right Node with 2646 Examples
# Creating Left Child Node With 27 Examples, and Right Node with 382 Examples
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 221 Examples, and Right Node with 161 Examples
# C(posterior=[],class=0,Purity=0.918552036199)
# C(posterior=[],class=0,Purity=0.968944099379)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 1954 Examples, and Right Node with 593 Examples
# Creating Left Child Node With 1041 Examples, and Right Node with 913 Examples
# Creating Left Child Node With 334 Examples, and Right Node with 707 Examples
# C(posterior=[],class=2,Purity=0.685628742515)
# C(posterior=[],class=2,Purity=0.983026874116)
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 16173 Examples, and Right Node with 8225 Examples
# Creating Left Child Node With 7377 Examples, and Right Node with 8796 Examples
# Creating Left Child Node With 2663 Examples, and Right Node with 4714 Examples
# Creating Left Child Node With 2663 Examples, and Right Node with 0 Examples
# C(posterior=[],class=2,Purity=0.445362373263)
# Creating Left Child Node With 1581 Examples, and Right Node with 3133 Examples
# C(posterior=[],class=0,Purity=0.731182795699)
# C(posterior=[],class=2,Purity=0.766358123205)
# Creating Left Child Node With 5448 Examples, and Right Node with 3348 Examples
# Creating Left Child Node With 3595 Examples, and Right Node with 1853 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=2,Purity=0.957366432812)
# Creating Left Child Node With 2229 Examples, and Right Node with 1119 Examples
# C(posterior=[],class=1,Purity=0.915208613728)
# C(posterior=[],class=0,Purity=0.951742627346)
# Creating Left Child Node With 6293 Examples, and Right Node with 1932 Examples
# Creating Left Child Node With 4437 Examples, and Right Node with 1856 Examples
# C(posterior=[],class=0,Purity=0.998422357449)
# Creating Left Child Node With 333 Examples, and Right Node with 1523 Examples
# C(posterior=[],class=0,Purity=0.933933933934)
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 24383 Examples, and Right Node with 5617 Examples
# Creating Left Child Node With 13637 Examples, and Right Node with 10746 Examples
# Creating Left Child Node With 1764 Examples, and Right Node with 11873 Examples
# C(posterior=[],class=0,Purity=0.999433106576)
# Creating Left Child Node With 9972 Examples, and Right Node with 1901 Examples
# Creating Left Child Node With 4099 Examples, and Right Node with 5873 Examples
# C(posterior=[],class=2,Purity=0.739448646011)
# C(posterior=[],class=0,Purity=0.695215392474)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 7557 Examples, and Right Node with 3189 Examples
# Creating Left Child Node With 2924 Examples, and Right Node with 4633 Examples
# Creating Left Child Node With 2556 Examples, and Right Node with 368 Examples
# C(posterior=[],class=1,Purity=0.984350547731)
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=1,Purity=0.984675156486)
# Creating Left Child Node With 1379 Examples, and Right Node with 1810 Examples
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 959 Examples, and Right Node with 851 Examples
# C(posterior=[],class=0,Purity=0.796663190824)
# C(posterior=[],class=0,Purity=0.998824911868)
# Creating Left Child Node With 1353 Examples, and Right Node with 4264 Examples
# Creating Left Child Node With 679 Examples, and Right Node with 674 Examples
# C(posterior=[],class=0,Purity=0.988217967599)
# Creating Left Child Node With 82 Examples, and Right Node with 592 Examples
# Creating Left Child Node With 72 Examples, and Right Node with 10 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.6)
# Creating Left Child Node With 329 Examples, and Right Node with 263 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=2,Purity=0.993667917448)
# Creating Left Child Node With 14120 Examples, and Right Node with 15880 Examples
# Creating Left Child Node With 4539 Examples, and Right Node with 9581 Examples
# Creating Left Child Node With 2170 Examples, and Right Node with 2369 Examples
# Creating Left Child Node With 245 Examples, and Right Node with 1925 Examples
# Creating Left Child Node With 245 Examples, and Right Node with 0 Examples
# C(posterior=[],class=0,Purity=0.926530612245)
# Creating Left Child Node With 1631 Examples, and Right Node with 294 Examples
# C(posterior=[],class=0,Purity=0.706315144083)
# C(posterior=[],class=0,Purity=0.914965986395)
# C(posterior=[],class=0,Purity=0.992823976361)
# Creating Left Child Node With 4567 Examples, and Right Node with 5014 Examples
# Creating Left Child Node With 953 Examples, and Right Node with 3614 Examples
# Creating Left Child Node With 471 Examples, and Right Node with 482 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.995850622407)
# Creating Left Child Node With 3045 Examples, and Right Node with 569 Examples
# C(posterior=[],class=2,Purity=0.967487684729)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 823 Examples, and Right Node with 4191 Examples
# Creating Left Child Node With 618 Examples, and Right Node with 205 Examples
# C(posterior=[],class=1,Purity=0.97572815534)
# C(posterior=[],class=2,Purity=0.941463414634)
# Creating Left Child Node With 3406 Examples, and Right Node with 785 Examples
# C(posterior=[],class=2,Purity=0.733411626541)
# C(posterior=[],class=2,Purity=0.997452229299)
# Creating Left Child Node With 7215 Examples, and Right Node with 8665 Examples
# C(posterior=[],class=1,Purity=0.996673596674)
# Creating Left Child Node With 2242 Examples, and Right Node with 6423 Examples
# Creating Left Child Node With 594 Examples, and Right Node with 1648 Examples
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 27 Examples, and Right Node with 1621 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=2,Purity=0.95126465145)
# Creating Left Child Node With 2496 Examples, and Right Node with 3927 Examples
# Creating Left Child Node With 2495 Examples, and Right Node with 1 Examples
# C(posterior=[],class=1,Purity=0.478156312625)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 2326 Examples, and Right Node with 1601 Examples
# C(posterior=[],class=0,Purity=0.804815133276)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 8229 Examples, and Right Node with 21771 Examples
# Creating Left Child Node With 4858 Examples, and Right Node with 3371 Examples
# Creating Left Child Node With 1417 Examples, and Right Node with 3441 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=0,Purity=0.969195001453)
# C(posterior=[],class=1,Purity=0.995550281815)
# Creating Left Child Node With 6959 Examples, and Right Node with 14812 Examples
# Creating Left Child Node With 2127 Examples, and Right Node with 4832 Examples
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 4320 Examples, and Right Node with 512 Examples
# Creating Left Child Node With 3488 Examples, and Right Node with 832 Examples
# C(posterior=[],class=2,Purity=0.911123853211)
# C(posterior=[],class=0,Purity=0.973557692308)
# Creating Left Child Node With 43 Examples, and Right Node with 469 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=0,Purity=0.995735607676)
# Creating Left Child Node With 6860 Examples, and Right Node with 7952 Examples
# Creating Left Child Node With 5825 Examples, and Right Node with 1035 Examples
# Creating Left Child Node With 4075 Examples, and Right Node with 1750 Examples
# C(posterior=[],class=2,Purity=0.715828220859)
# C(posterior=[],class=2,Purity=0.981142857143)
# Creating Left Child Node With 577 Examples, and Right Node with 458 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=2,Purity=0.606986899563)
# Creating Left Child Node With 5280 Examples, and Right Node with 2672 Examples
# Creating Left Child Node With 2505 Examples, and Right Node with 2775 Examples
# C(posterior=[],class=2,Purity=0.647105788423)
# C(posterior=[],class=1,Purity=0.655855855856)
# C(posterior=[],class=1,Purity=0.998128742515)
# Creating Left Child Node With 12094 Examples, and Right Node with 17906 Examples
# Creating Left Child Node With 8597 Examples, and Right Node with 3497 Examples
# Creating Left Child Node With 8394 Examples, and Right Node with 203 Examples
# Creating Left Child Node With 5370 Examples, and Right Node with 3024 Examples
# C(posterior=[],class=2,Purity=0.979515828678)
# Creating Left Child Node With 578 Examples, and Right Node with 2446 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=0,Purity=0.795993458708)
# Creating Left Child Node With 182 Examples, and Right Node with 21 Examples
# C(posterior=[],class=0,Purity=0.967032967033)
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=0,Purity=0.997140406062)
# Creating Left Child Node With 8386 Examples, and Right Node with 9520 Examples
# Creating Left Child Node With 6372 Examples, and Right Node with 2014 Examples
# Creating Left Child Node With 1244 Examples, and Right Node with 5128 Examples
# Creating Left Child Node With 827 Examples, and Right Node with 417 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=2,Purity=0.781774580336)
# Creating Left Child Node With 379 Examples, and Right Node with 4749 Examples
# C(posterior=[],class=0,Purity=0.973614775726)
# C(posterior=[],class=1,Purity=0.997262581596)
# Creating Left Child Node With 981 Examples, and Right Node with 1033 Examples
# Creating Left Child Node With 623 Examples, and Right Node with 358 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 6024 Examples, and Right Node with 3496 Examples
# Creating Left Child Node With 3571 Examples, and Right Node with 2453 Examples
# C(posterior=[],class=0,Purity=0.991038924671)
# Creating Left Child Node With 2453 Examples, and Right Node with 0 Examples
# C(posterior=[],class=2,Purity=0.472482674276)
# Creating Left Child Node With 2842 Examples, and Right Node with 654 Examples
# C(posterior=[],class=1,Purity=0.960239268121)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 11778 Examples, and Right Node with 18222 Examples
# Creating Left Child Node With 9514 Examples, and Right Node with 2264 Examples
# Creating Left Child Node With 1579 Examples, and Right Node with 7935 Examples
# C(posterior=[],class=0,Purity=0.989867004433)
# Creating Left Child Node With 5065 Examples, and Right Node with 2870 Examples
# Creating Left Child Node With 3381 Examples, and Right Node with 1684 Examples
# C(posterior=[],class=2,Purity=0.996746524697)
# C(posterior=[],class=1,Purity=0.5)
# Creating Left Child Node With 1553 Examples, and Right Node with 1317 Examples
# C(posterior=[],class=0,Purity=0.951706374759)
# C(posterior=[],class=2,Purity=0.669703872437)
# C(posterior=[],class=0,Purity=0.961130742049)
# Creating Left Child Node With 3794 Examples, and Right Node with 14428 Examples
# Creating Left Child Node With 3401 Examples, and Right Node with 393 Examples
# C(posterior=[],class=0,Purity=0.993237283152)
# Creating Left Child Node With 393 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 317 Examples, and Right Node with 76 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=0,Purity=0.736842105263)
# Creating Left Child Node With 9776 Examples, and Right Node with 4652 Examples
# Creating Left Child Node With 8050 Examples, and Right Node with 1726 Examples
# C(posterior=[],class=1,Purity=0.993664596273)
# Creating Left Child Node With 1106 Examples, and Right Node with 620 Examples
# C(posterior=[],class=2,Purity=0.982820976492)
# C(posterior=[],class=1,Purity=0.488709677419)
# Creating Left Child Node With 4078 Examples, and Right Node with 574 Examples
# Creating Left Child Node With 416 Examples, and Right Node with 3662 Examples
# C(posterior=[],class=1,Purity=0.834134615385)
# C(posterior=[],class=2,Purity=0.996450027307)
# C(posterior=[],class=0,Purity=0.965156794425)
# Creating Left Child Node With 23680 Examples, and Right Node with 6320 Examples
# Creating Left Child Node With 7962 Examples, and Right Node with 15718 Examples
# Creating Left Child Node With 4434 Examples, and Right Node with 3528 Examples
# Creating Left Child Node With 2300 Examples, and Right Node with 2134 Examples
# Creating Left Child Node With 2052 Examples, and Right Node with 248 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=1,Purity=0.983870967742)
# C(posterior=[],class=1,Purity=0.980318650422)
# C(posterior=[],class=0,Purity=0.979308390023)
# Creating Left Child Node With 12322 Examples, and Right Node with 3396 Examples
# Creating Left Child Node With 8430 Examples, and Right Node with 3892 Examples
# Creating Left Child Node With 5631 Examples, and Right Node with 2799 Examples
# C(posterior=[],class=2,Purity=0.668797726869)
# C(posterior=[],class=1,Purity=0.642372275813)
# Creating Left Child Node With 3307 Examples, and Right Node with 585 Examples
# C(posterior=[],class=2,Purity=0.957060780163)
# C(posterior=[],class=0,Purity=0.955555555556)
# Creating Left Child Node With 1490 Examples, and Right Node with 1906 Examples
# Creating Left Child Node With 311 Examples, and Right Node with 1179 Examples
# C(posterior=[],class=1,Purity=0.610932475884)
# C(posterior=[],class=0,Purity=0.808312128923)
# C(posterior=[],class=0,Purity=0.956977964323)
# Creating Left Child Node With 4302 Examples, and Right Node with 2018 Examples
# Creating Left Child Node With 1568 Examples, and Right Node with 2734 Examples
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 1932 Examples, and Right Node with 802 Examples
# Creating Left Child Node With 1549 Examples, and Right Node with 383 Examples
# C(posterior=[],class=1,Purity=0.998708844416)
# C(posterior=[],class=2,Purity=0.882506527415)
# C(posterior=[],class=2,Purity=0.997506234414)
# C(posterior=[],class=1,Purity=0.990089197225)
# Creating Left Child Node With 11986 Examples, and Right Node with 18014 Examples
# Creating Left Child Node With 11300 Examples, and Right Node with 686 Examples
# Creating Left Child Node With 6762 Examples, and Right Node with 4538 Examples
# Creating Left Child Node With 5358 Examples, and Right Node with 1404 Examples
# Creating Left Child Node With 2946 Examples, and Right Node with 2412 Examples
# C(posterior=[],class=0,Purity=0.821113374067)
# C(posterior=[],class=1,Purity=0.858623548922)
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=1,Purity=0.996033494932)
# Creating Left Child Node With 0 Examples, and Right Node with 686 Examples
# Creating Left Child Node With 554 Examples, and Right Node with 132 Examples
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 79 Examples, and Right Node with 53 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 7714 Examples, and Right Node with 10300 Examples
# Creating Left Child Node With 736 Examples, and Right Node with 6978 Examples
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 5243 Examples, and Right Node with 1735 Examples
# Creating Left Child Node With 3421 Examples, and Right Node with 1822 Examples
# C(posterior=[],class=0,Purity=0.699503069278)
# C(posterior=[],class=0,Purity=0.980241492865)
# Creating Left Child Node With 554 Examples, and Right Node with 1181 Examples
# C(posterior=[],class=0,Purity=0.992779783394)
# C(posterior=[],class=1,Purity=0.984758679086)
# Creating Left Child Node With 4768 Examples, and Right Node with 5532 Examples
# Creating Left Child Node With 619 Examples, and Right Node with 4149 Examples
# Creating Left Child Node With 10 Examples, and Right Node with 609 Examples
# C(posterior=[],class=2,Purity=0.8)
# C(posterior=[],class=2,Purity=0.949096880131)
# Creating Left Child Node With 2661 Examples, and Right Node with 1488 Examples
# C(posterior=[],class=2,Purity=0.734686208192)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 3367 Examples, and Right Node with 2165 Examples
# Creating Left Child Node With 3022 Examples, and Right Node with 345 Examples
# C(posterior=[],class=2,Purity=0.907015221707)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 1238 Examples, and Right Node with 927 Examples
# C(posterior=[],class=2,Purity=0.996768982229)
# C(posterior=[],class=1,Purity=0.994606256742)
# Creating Left Child Node With 22450 Examples, and Right Node with 7550 Examples
# Creating Left Child Node With 5224 Examples, and Right Node with 17226 Examples
# Creating Left Child Node With 3864 Examples, and Right Node with 1360 Examples
# Creating Left Child Node With 2947 Examples, and Right Node with 917 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=1,Purity=0.961832061069)
# Creating Left Child Node With 713 Examples, and Right Node with 647 Examples
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 97 Examples, and Right Node with 550 Examples
# C(posterior=[],class=1,Purity=0.752577319588)
# C(posterior=[],class=0,Purity=0.992727272727)
# Creating Left Child Node With 4122 Examples, and Right Node with 13104 Examples
# Creating Left Child Node With 1135 Examples, and Right Node with 2987 Examples
# Creating Left Child Node With 82 Examples, and Right Node with 1053 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.819563152896)
# C(posterior=[],class=0,Purity=0.99765651155)
# Creating Left Child Node With 4363 Examples, and Right Node with 8741 Examples
# Creating Left Child Node With 1328 Examples, and Right Node with 3035 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=1,Purity=0.999670510708)
# Creating Left Child Node With 6302 Examples, and Right Node with 2439 Examples
# C(posterior=[],class=2,Purity=0.563630593462)
# C(posterior=[],class=2,Purity=0.963509635096)
# Creating Left Child Node With 2376 Examples, and Right Node with 5174 Examples
# Creating Left Child Node With 467 Examples, and Right Node with 1909 Examples
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 351 Examples, and Right Node with 1558 Examples
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 839 Examples, and Right Node with 719 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 4653 Examples, and Right Node with 521 Examples
# Creating Left Child Node With 4144 Examples, and Right Node with 509 Examples
# C(posterior=[],class=1,Purity=0.999758687259)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 521 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 209 Examples, and Right Node with 312 Examples
# C(posterior=[],class=2,Purity=0.846889952153)
# C(posterior=[],class=1,Purity=0.983974358974)
# Creating Left Child Node With 5695 Examples, and Right Node with 24305 Examples
# Creating Left Child Node With 3454 Examples, and Right Node with 2241 Examples
# Creating Left Child Node With 2966 Examples, and Right Node with 488 Examples
# C(posterior=[],class=2,Purity=0.996965610249)
# Creating Left Child Node With 99 Examples, and Right Node with 389 Examples
# Creating Left Child Node With 88 Examples, and Right Node with 11 Examples
# C(posterior=[],class=0,Purity=0.829545454545)
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 1011 Examples, and Right Node with 1230 Examples
# Creating Left Child Node With 607 Examples, and Right Node with 404 Examples
# C(posterior=[],class=0,Purity=0.993410214168)
# C(posterior=[],class=2,Purity=0.950495049505)
# C(posterior=[],class=2,Purity=0.969918699187)
# Creating Left Child Node With 20042 Examples, and Right Node with 4263 Examples
# Creating Left Child Node With 6055 Examples, and Right Node with 13987 Examples
# Creating Left Child Node With 2848 Examples, and Right Node with 3207 Examples
# C(posterior=[],class=1,Purity=0.993328651685)
# Creating Left Child Node With 1073 Examples, and Right Node with 2134 Examples
# C(posterior=[],class=0,Purity=0.83504193849)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 8989 Examples, and Right Node with 4998 Examples
# Creating Left Child Node With 4062 Examples, and Right Node with 4927 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=0,Purity=0.422772478181)
# Creating Left Child Node With 1144 Examples, and Right Node with 3854 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=1,Purity=0.662428645563)
# Creating Left Child Node With 1675 Examples, and Right Node with 2588 Examples
# C(posterior=[],class=0,Purity=0.997611940299)
# C(posterior=[],class=2,Purity=0.999227202473)

# %%
#Training Confusion Matrix
Yp=rfc.predict(X)
print Y.shape, len(Yp)
t.print_confusion_matrix(Yp,Y)
# Out:
# (30000L,) 30000
# Predicted     0      1      2    All
# Actual
# 0          9639    273     88  10000
# 1             4   9941     55  10000
# 2            14     15   9971  10000
# All        9657  10229  10114  30000

# %%
#Testing Confusion Matrix
Ypt=rfc.predict(Xtest)
print Y.shape, len(Ypt)
t.print_confusion_matrix(Ypt,Ytest)
# Out:
# (30000L,) 15000
# Predicted     0     1     2    All
# Actual
# 0          4821   133    46   5000
# 1             2  4965    33   5000
# 2             5     6  4989   5000
# All        4828  5104  5068  15000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Y.flatten() ==  np.array(Yp)) / float(Y.shape[0]) 

assert_greater_equal(acc, 0.78)

# %%
t.plot_points_range(rfc,X,Y)
# Out:
# (10000L, 2L)
# [0, 1, 2]

# %%
t.plot_decision_regions(X,Y,rfc,res=0.1)

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
# %pdb
ntrees=rfc.ntrees
nrows=ntrees/2
ncols=2
i=0
plt.subplots(nrows,ncols,figsize=(16,40))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i+1);
    t.plot_decision_regions(X,Y,clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i+1))
    i=i+1
plt.tight_layout
# Out:
# Automatic pdb calling has been turned ON
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# ## TODO: Find Optimal Number of Trees for this data set, using cross validation...

# %%
X,Y=t.get_spherical_data(N=10000)
print X.shape, Y.shape
Xtest,Ytest=t.get_spherical_data(N=5000)

trees = np.arange(1, 21)

for tree in trees:
    rfc=rf.RandomForest(weaklearner='Conic',usebagging=False,ntrees=tree)
    rfc.train(X,Y[:,np.newaxis])

    Ypt=rfc.predict(Xtest)

    acc = np.sum(Ytest ==  np.array(Ypt)) / float(Ytest.shape[0]) 

    print "Trees=", tree, " and Accuracy=", acc
