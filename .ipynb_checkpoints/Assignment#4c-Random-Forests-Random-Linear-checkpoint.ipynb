# %% [markdown]
# # Assignment No 4c
# ###### *Sibt ul Hussain*
# ----
# ## Goal
#
# Your goal in this assigment is to implement and test different variants of Random Forests.For this part you will be implementing randomized version of **Randomized Linear** weak learner based Random Forest, i.e. you will be randomly selecting a pair of  features from all set of features and than randomly selecting the parameters for a generic equation of line,i.e. $ax+by+c=0$.
#
# ## TODO:
#
# **Complete the child class LinearWeakLearner in file `weaklearner.py` by writing the missing code.**
#
# **Note** Please note that you are allowed to use only those libraries which we have discussed in the class, i.e. numpy, scipy, pandas.
#
# ## Submission Instructions
# You are required to submit the original notebook file on the Slate (with .ipynb extension), with complete set of outputs. Students failing to do so will get zero marks.
#
# *Please read each step carefully and understand it fully before proceeding with code writing*
#
# ## Plagiarism
# Any form of plagiarism will not be tolerated and result in 0 marks.

# %%
# %pylab inline
import scipy.stats
from collections import defaultdict  # default dictionary 
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)
# %load_ext autoreload 
# %autoreload 2
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# C:\Anaconda3\envs\taship\lib\site-packages\IPython\core\magics\pylab.py:161: UserWarning: pylab import has clobbered these variables: ['cov']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
import pandas as pd
import tools as t # set of tools for plotting, data splitting, etc..
import time

# %%
# Create some dummy data for testing
np.random.seed(seed=99)

# %% [markdown]
# ## Let's cook some data up for a multi-class classification problem...

# %%
#generate training and testing set...by sampling from mutli-variate Gaussian
cp=5
nclasses=2
mean1 = [-cp,-cp]
mean2 = [cp,cp]
mean3 = [cp,-cp]
mean4 = [-cp,cp]
cov = [[3.0,0.0],[0.0,3.0]] 

#create some points for the training set...
nexamples=2000
x1 = np.random.multivariate_normal(mean1,cov,nexamples/4)
x2 = np.random.multivariate_normal(mean2,cov,nexamples/4)
x3 = np.random.multivariate_normal(mean3,cov,nexamples/4)
x4 = np.random.multivariate_normal(mean4,cov,nexamples/4)

X=np.vstack((x1,x2,x3,x4))
Y=np.vstack((1*np.ones((nexamples/4,1)),2*np.ones((nexamples/4,1)),3*np.ones((nexamples/4,1)),4*np.ones((nexamples/4,1))))


plt.scatter(x1[:,0],x1[:,1], c='r', s=100)
plt.scatter(x2[:,0],x2[:,1], c='g', s=100)            
plt.scatter(x3[:,0],x3[:,1], c='b', s=100)
plt.scatter(x4[:,0],x4[:,1], c='y', s=100)            



plt.title("Multi-class Classification")
plt.xlabel("feature $x_1$")
plt.ylabel("feature $x_2$")
plt.legend(['r','g','b','y'])
fig_ml_in_10 = plt.gcf()
plt.savefig('multi-linear-class.svg',format='svg')
#create some points for the training set..

ntexamples=1000
x1 = np.random.multivariate_normal(mean1,cov,ntexamples/4)
x2 = np.random.multivariate_normal(mean2,cov,ntexamples/4)
x3 = np.random.multivariate_normal(mean3,cov,ntexamples/4)
x4 = np.random.multivariate_normal(mean4,cov,ntexamples/4)

Xt=np.vstack((x1,x2,x3,x4))
Yt=np.vstack((1*np.ones((ntexamples/4,1)),2*np.ones((ntexamples/4,1)),3*np.ones((ntexamples/4,1)),4*np.ones((ntexamples/4,1))))

# %%
import randomForest as rf

# %%
rfc=rf.RandomForest(weaklearner='Linear')

# %%
print X.shape, Y.shape
# Out:
# (2000L, 2L) (2000L, 1L)

# %%
rfc.train(X,Y)
# Out:
# Creating Left Child Node With 999 Examples, and Right Node with 1001 Examples
# Creating Left Child Node With 484 Examples, and Right Node with 515 Examples
# C(posterior=[],class=4.0,Purity=0.98347107438)
# C(posterior=[],class=1.0,Purity=0.953398058252)
# Creating Left Child Node With 184 Examples, and Right Node with 817 Examples
# Creating Left Child Node With 111 Examples, and Right Node with 73 Examples
# Creating Left Child Node With 95 Examples, and Right Node with 16 Examples
# C(posterior=[],class=2.0,Purity=1.0)
# C(posterior=[],class=3.0,Purity=1.0)
# C(posterior=[],class=3.0,Purity=0.958904109589)
# Creating Left Child Node With 407 Examples, and Right Node with 410 Examples
# C(posterior=[],class=3.0,Purity=1.0)
# C(posterior=[],class=2.0,Purity=0.982926829268)
# Creating Left Child Node With 976 Examples, and Right Node with 1024 Examples
# Creating Left Child Node With 968 Examples, and Right Node with 8 Examples
# Creating Left Child Node With 510 Examples, and Right Node with 458 Examples
# Creating Left Child Node With 486 Examples, and Right Node with 24 Examples
# C(posterior=[],class=4.0,Purity=0.995884773663)
# C(posterior=[],class=1.0,Purity=1.0)
# C(posterior=[],class=1.0,Purity=0.997816593886)
# C(posterior=[],class=4.0,Purity=1.0)
# Creating Left Child Node With 514 Examples, and Right Node with 510 Examples
# C(posterior=[],class=3.0,Purity=0.966926070039)
# C(posterior=[],class=2.0,Purity=0.980392156863)
# Creating Left Child Node With 1420 Examples, and Right Node with 580 Examples
# Creating Left Child Node With 904 Examples, and Right Node with 516 Examples
# Creating Left Child Node With 409 Examples, and Right Node with 495 Examples
# C(posterior=[],class=3.0,Purity=0.98533007335)
# C(posterior=[],class=1.0,Purity=0.99595959596)
# C(posterior=[],class=4.0,Purity=0.96511627907)
# Creating Left Child Node With 97 Examples, and Right Node with 483 Examples
# C(posterior=[],class=3.0,Purity=0.989690721649)
# C(posterior=[],class=2.0,Purity=0.997929606625)
# Creating Left Child Node With 1016 Examples, and Right Node with 984 Examples
# Creating Left Child Node With 448 Examples, and Right Node with 568 Examples
# C(posterior=[],class=3.0,Purity=0.997767857143)
# Creating Left Child Node With 461 Examples, and Right Node with 107 Examples
# C(posterior=[],class=1.0,Purity=0.95010845987)
# Creating Left Child Node With 53 Examples, and Right Node with 54 Examples
# Creating Left Child Node With 17 Examples, and Right Node with 36 Examples
# C(posterior=[],class=3.0,Purity=0.529411764706)
# C(posterior=[],class=3.0,Purity=1.0)
# C(posterior=[],class=1.0,Purity=1.0)
# Creating Left Child Node With 546 Examples, and Right Node with 438 Examples
# Creating Left Child Node With 507 Examples, and Right Node with 39 Examples
# C(posterior=[],class=2.0,Purity=0.98224852071)
# Creating Left Child Node With 28 Examples, and Right Node with 11 Examples
# Creating Left Child Node With 21 Examples, and Right Node with 7 Examples
# C(posterior=[],class=4.0,Purity=1.0)
# C(posterior=[],class=4.0,Purity=0.714285714286)
# C(posterior=[],class=4.0,Purity=1.0)
# C(posterior=[],class=4.0,Purity=1.0)
# Creating Left Child Node With 986 Examples, and Right Node with 1014 Examples
# Creating Left Child Node With 4 Examples, and Right Node with 982 Examples
# C(posterior=[],class=4.0,Purity=1.0)
# Creating Left Child Node With 806 Examples, and Right Node with 176 Examples
# Creating Left Child Node With 406 Examples, and Right Node with 400 Examples
# C(posterior=[],class=4.0,Purity=0.987684729064)
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 97 Examples, and Right Node with 79 Examples
# C(posterior=[],class=4.0,Purity=0.969072164948)
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 501 Examples, and Right Node with 513 Examples
# C(posterior=[],class=1.0,Purity=0.984031936128)
# C(posterior=[],class=3.0,Purity=0.964912280702)
# Creating Left Child Node With 979 Examples, and Right Node with 1021 Examples
# Creating Left Child Node With 298 Examples, and Right Node with 681 Examples
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 211 Examples, and Right Node with 470 Examples
# Creating Left Child Node With 175 Examples, and Right Node with 36 Examples
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 2 Examples, and Right Node with 34 Examples
# C(posterior=[],class=2.0,Purity=1.0)
# C(posterior=[],class=3.0,Purity=0.882352941176)
# C(posterior=[],class=3.0,Purity=0.997872340426)
# Creating Left Child Node With 521 Examples, and Right Node with 500 Examples
# C(posterior=[],class=1.0,Purity=0.957773512476)
# C(posterior=[],class=4.0,Purity=0.96)
# Creating Left Child Node With 1013 Examples, and Right Node with 987 Examples
# Creating Left Child Node With 501 Examples, and Right Node with 512 Examples
# C(posterior=[],class=1.0,Purity=0.988023952096)
# C(posterior=[],class=4.0,Purity=0.974609375)
# Creating Left Child Node With 492 Examples, and Right Node with 495 Examples
# C(posterior=[],class=2.0,Purity=0.997967479675)
# C(posterior=[],class=3.0,Purity=0.99595959596)
# Creating Left Child Node With 1097 Examples, and Right Node with 903 Examples
# Creating Left Child Node With 597 Examples, and Right Node with 500 Examples
# Creating Left Child Node With 497 Examples, and Right Node with 100 Examples
# C(posterior=[],class=2.0,Purity=0.997987927565)
# C(posterior=[],class=3.0,Purity=0.99)
# C(posterior=[],class=4.0,Purity=0.99)
# Creating Left Child Node With 397 Examples, and Right Node with 506 Examples
# C(posterior=[],class=3.0,Purity=0.984886649874)
# C(posterior=[],class=1.0,Purity=0.97233201581)
# Creating Left Child Node With 1007 Examples, and Right Node with 993 Examples
# Creating Left Child Node With 527 Examples, and Right Node with 480 Examples
# Creating Left Child Node With 501 Examples, and Right Node with 26 Examples
# C(posterior=[],class=2.0,Purity=0.996007984032)
# Creating Left Child Node With 4 Examples, and Right Node with 22 Examples
# C(posterior=[],class=3.0,Purity=0.75)
# C(posterior=[],class=3.0,Purity=0.954545454545)
# C(posterior=[],class=3.0,Purity=0.991666666667)
# Creating Left Child Node With 482 Examples, and Right Node with 511 Examples
# C(posterior=[],class=1.0,Purity=1.0)
# C(posterior=[],class=4.0,Purity=0.974559686888)
# Creating Left Child Node With 1005 Examples, and Right Node with 995 Examples
# Creating Left Child Node With 986 Examples, and Right Node with 19 Examples
# Creating Left Child Node With 497 Examples, and Right Node with 489 Examples
# C(posterior=[],class=4.0,Purity=0.989939637827)
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 8 Examples, and Right Node with 11 Examples
# Creating Left Child Node With 4 Examples, and Right Node with 4 Examples
# C(posterior=[],class=4.0,Purity=1.0)
# C(posterior=[],class=4.0,Purity=0.75)
# Creating Left Child Node With 2 Examples, and Right Node with 9 Examples
# C(posterior=[],class=2.0,Purity=1.0)
# Creating Left Child Node With 8 Examples, and Right Node with 1 Examples
# C(posterior=[],class=2.0,Purity=0.75)
# C(posterior=[],class=3.0,Purity=1.0)
# Creating Left Child Node With 491 Examples, and Right Node with 504 Examples
# C(posterior=[],class=1.0,Purity=0.997963340122)
# C(posterior=[],class=3.0,Purity=0.986111111111)

# %%
len(rfc.trees)
# Out:
# 10

# %%
# Training Confusion Matrix...
Yp=rfc.predict(X)
print Y.shape, len(Yp)
t.print_confusion_matrix(Yp,Y)
# Out:
# (2000L, 1L) 2000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        494    0    4    2   500
# 2.0          0  497    0    3   500
# 3.0          0    1  499    0   500
# 4.0          1    0    0  499   500
# All        495  498  503  504  2000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Y ==  np.array(Yp)) / float(Y.shape[0])

assert_greater_equal(acc, 0.78)

# %%
print acc
# Out:
# 0.9945

# %%
#It might take time, a little longer than the desired
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('training-boundary-rf-rlinear-10trees.svg',format='svg')

# %%
#Testing Confusion Matrix...
Ypt=rfc.predict(Xt)
print Y.shape, len(Ypt)
t.print_confusion_matrix(Ypt,Yt)
# Out:
# (2000L, 1L) 1000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        249    0    1    0   250
# 2.0          0  248    1    1   250
# 3.0          0    1  249    0   250
# 4.0          1    0    0  249   250
# All        250  249  251  250  1000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Yt ==  np.array(Ypt)) / float(Yt.shape[0]) 

assert_greater_equal(acc, 0.78)

# %%
print acc
# Out:
# 0.995

# %%
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('testing-boundary-rf-raa-10trees.svg',format='svg')

# %%
#plt.style.use('ggplot')
#matplotlib.rcParams['figure.figsize'] = (14.0, 8.0)
# %pdb
t.plot_points_range(rfc,X,Y,10000)
# Out:
# Automatic pdb calling has been turned OFF
# (10000L, 2L)
# [1.0, 2.0, 3.0, 4.0]

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
ntrees=rfc.ntrees
nrows=ntrees/2
ncols=2
i=1
plt.subplots(nrows,ncols,figsize=(16,20))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    t.plot_decision_regions(X,np.squeeze(Y),clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# #### What Can You conclude

# %% [markdown]
# ## Lets Run on Nonlinear Data, The Spherical Examples...

# %%
#Get Training Data from a spherical distribution and ...
X,Y=t.get_spherical_data(N=10000)

# %%
print X.shape, Y.shape
# Out:
# (30000L, 2L) (30000L,)

# %%
#Get Test Data 
Xtest,Ytest=t.get_spherical_data(N=5000)

# %%
rfc=rf.RandomForest(weaklearner='Linear',usebagging=False,ntrees=20)
rfc.train(X,Y[:,np.newaxis])
# Out:
# Creating Left Child Node With 11805 Examples, and Right Node with 18195 Examples
# Creating Left Child Node With 7754 Examples, and Right Node with 4051 Examples
# Creating Left Child Node With 1602 Examples, and Right Node with 6152 Examples
# Creating Left Child Node With 1602 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 1061 Examples, and Right Node with 541 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=1,Purity=0.536044362292)
# Creating Left Child Node With 5711 Examples, and Right Node with 441 Examples
# C(posterior=[],class=2,Purity=0.992470670636)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 1351 Examples, and Right Node with 2700 Examples
# Creating Left Child Node With 321 Examples, and Right Node with 1030 Examples
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 74 Examples, and Right Node with 956 Examples
# C(posterior=[],class=2,Purity=0.648648648649)
# C(posterior=[],class=0,Purity=0.833682008368)
# C(posterior=[],class=0,Purity=0.998148148148)
# Creating Left Child Node With 5611 Examples, and Right Node with 12584 Examples
# Creating Left Child Node With 2877 Examples, and Right Node with 2734 Examples
# C(posterior=[],class=1,Purity=0.973236009732)
# C(posterior=[],class=2,Purity=0.999634235552)
# Creating Left Child Node With 10244 Examples, and Right Node with 2340 Examples
# Creating Left Child Node With 7988 Examples, and Right Node with 2256 Examples
# Creating Left Child Node With 2529 Examples, and Right Node with 5459 Examples
# C(posterior=[],class=1,Purity=0.985765124555)
# C(posterior=[],class=0,Purity=0.742260487269)
# Creating Left Child Node With 1996 Examples, and Right Node with 260 Examples
# C(posterior=[],class=1,Purity=0.999498997996)
# C(posterior=[],class=0,Purity=0.861538461538)
# C(posterior=[],class=1,Purity=0.974358974359)
# Creating Left Child Node With 26004 Examples, and Right Node with 3996 Examples
# Creating Left Child Node With 13562 Examples, and Right Node with 12442 Examples
# Creating Left Child Node With 7738 Examples, and Right Node with 5824 Examples
# Creating Left Child Node With 6415 Examples, and Right Node with 1323 Examples
# Creating Left Child Node With 4094 Examples, and Right Node with 2321 Examples
# C(posterior=[],class=2,Purity=0.777723497802)
# C(posterior=[],class=0,Purity=0.705730288669)
# Creating Left Child Node With 328 Examples, and Right Node with 995 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.579899497487)
# Creating Left Child Node With 3027 Examples, and Right Node with 2797 Examples
# C(posterior=[],class=0,Purity=0.99074991741)
# Creating Left Child Node With 175 Examples, and Right Node with 2622 Examples
# C(posterior=[],class=2,Purity=0.92)
# C(posterior=[],class=0,Purity=0.896643783371)
# Creating Left Child Node With 3727 Examples, and Right Node with 8715 Examples
# Creating Left Child Node With 232 Examples, and Right Node with 3495 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.990557939914)
# Creating Left Child Node With 5609 Examples, and Right Node with 3106 Examples
# C(posterior=[],class=1,Purity=0.984845783562)
# Creating Left Child Node With 901 Examples, and Right Node with 2205 Examples
# C(posterior=[],class=0,Purity=0.956714761376)
# C(posterior=[],class=2,Purity=0.890249433107)
# C(posterior=[],class=1,Purity=0.997747747748)
# Creating Left Child Node With 11543 Examples, and Right Node with 18457 Examples
# Creating Left Child Node With 8300 Examples, and Right Node with 3243 Examples
# Creating Left Child Node With 2399 Examples, and Right Node with 5901 Examples
# Creating Left Child Node With 990 Examples, and Right Node with 1409 Examples
# C(posterior=[],class=0,Purity=0.969696969697)
# Creating Left Child Node With 350 Examples, and Right Node with 1059 Examples
# C(posterior=[],class=1,Purity=0.714285714286)
# C(posterior=[],class=0,Purity=0.998111425873)
# C(posterior=[],class=2,Purity=0.965599051008)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 14729 Examples, and Right Node with 3728 Examples
# Creating Left Child Node With 10595 Examples, and Right Node with 4134 Examples
# Creating Left Child Node With 5555 Examples, and Right Node with 5040 Examples
# Creating Left Child Node With 3750 Examples, and Right Node with 1805 Examples
# C(posterior=[],class=0,Purity=0.397866666667)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 4473 Examples, and Right Node with 567 Examples
# C(posterior=[],class=0,Purity=0.659065504136)
# C(posterior=[],class=1,Purity=0.99823633157)
# C(posterior=[],class=1,Purity=0.99854862119)
# Creating Left Child Node With 393 Examples, and Right Node with 3335 Examples
# C(posterior=[],class=2,Purity=0.992366412214)
# Creating Left Child Node With 2651 Examples, and Right Node with 684 Examples
# Creating Left Child Node With 260 Examples, and Right Node with 2391 Examples
# C(posterior=[],class=1,Purity=0.823076923077)
# C(posterior=[],class=2,Purity=0.998327059808)
# C(posterior=[],class=1,Purity=0.960526315789)
# Creating Left Child Node With 24811 Examples, and Right Node with 5189 Examples
# Creating Left Child Node With 18773 Examples, and Right Node with 6038 Examples
# Creating Left Child Node With 3673 Examples, and Right Node with 15100 Examples
# C(posterior=[],class=0,Purity=0.989381976586)
# Creating Left Child Node With 11803 Examples, and Right Node with 3297 Examples
# Creating Left Child Node With 2807 Examples, and Right Node with 8996 Examples
# C(posterior=[],class=0,Purity=0.891343070894)
# C(posterior=[],class=2,Purity=0.697087594486)
# C(posterior=[],class=0,Purity=0.974825599029)
# Creating Left Child Node With 1152 Examples, and Right Node with 4886 Examples
# Creating Left Child Node With 1070 Examples, and Right Node with 82 Examples
# C(posterior=[],class=2,Purity=0.965420560748)
# Creating Left Child Node With 34 Examples, and Right Node with 48 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 2150 Examples, and Right Node with 2736 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 4724 Examples, and Right Node with 465 Examples
# C(posterior=[],class=1,Purity=0.995977984759)
# C(posterior=[],class=2,Purity=0.950537634409)
# Creating Left Child Node With 20160 Examples, and Right Node with 9840 Examples
# Creating Left Child Node With 14071 Examples, and Right Node with 6089 Examples
# Creating Left Child Node With 4533 Examples, and Right Node with 9538 Examples
# Creating Left Child Node With 4207 Examples, and Right Node with 326 Examples
# C(posterior=[],class=1,Purity=0.970763014024)
# C(posterior=[],class=2,Purity=0.978527607362)
# Creating Left Child Node With 4922 Examples, and Right Node with 4616 Examples
# Creating Left Child Node With 3895 Examples, and Right Node with 1027 Examples
# C(posterior=[],class=0,Purity=0.827471116816)
# C(posterior=[],class=0,Purity=0.89970788705)
# Creating Left Child Node With 1234 Examples, and Right Node with 3382 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=0,Purity=0.566232998226)
# Creating Left Child Node With 1792 Examples, and Right Node with 4297 Examples
# C(posterior=[],class=1,Purity=0.983816964286)
# Creating Left Child Node With 3150 Examples, and Right Node with 1147 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 3257 Examples, and Right Node with 6583 Examples
# Creating Left Child Node With 252 Examples, and Right Node with 3005 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.985024958403)
# Creating Left Child Node With 3735 Examples, and Right Node with 2848 Examples
# Creating Left Child Node With 2428 Examples, and Right Node with 1307 Examples
# C(posterior=[],class=0,Purity=0.997116968699)
# Creating Left Child Node With 751 Examples, and Right Node with 556 Examples
# C(posterior=[],class=0,Purity=0.984021304927)
# C(posterior=[],class=2,Purity=0.960431654676)
# Creating Left Child Node With 1590 Examples, and Right Node with 1258 Examples
# Creating Left Child Node With 562 Examples, and Right Node with 1028 Examples
# C(posterior=[],class=0,Purity=0.818505338078)
# C(posterior=[],class=2,Purity=0.959143968872)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 6659 Examples, and Right Node with 23341 Examples
# Creating Left Child Node With 1338 Examples, and Right Node with 5321 Examples
# C(posterior=[],class=0,Purity=0.970852017937)
# Creating Left Child Node With 0 Examples, and Right Node with 5321 Examples
# Creating Left Child Node With 4251 Examples, and Right Node with 1070 Examples
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 535 Examples, and Right Node with 535 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=1,Purity=0.885981308411)
# Creating Left Child Node With 18372 Examples, and Right Node with 4969 Examples
# Creating Left Child Node With 11922 Examples, and Right Node with 6450 Examples
# Creating Left Child Node With 6892 Examples, and Right Node with 5030 Examples
# Creating Left Child Node With 1609 Examples, and Right Node with 5283 Examples
# C(posterior=[],class=0,Purity=0.560596643878)
# C(posterior=[],class=2,Purity=0.599659284497)
# C(posterior=[],class=0,Purity=0.9662027833)
# Creating Left Child Node With 4394 Examples, and Right Node with 2056 Examples
# C(posterior=[],class=1,Purity=0.963814292217)
# Creating Left Child Node With 1054 Examples, and Right Node with 1002 Examples
# C(posterior=[],class=2,Purity=0.591081593928)
# C(posterior=[],class=2,Purity=0.619760479042)
# C(posterior=[],class=1,Purity=0.994365063393)
# Creating Left Child Node With 26384 Examples, and Right Node with 3616 Examples
# Creating Left Child Node With 9235 Examples, and Right Node with 17149 Examples
# Creating Left Child Node With 2093 Examples, and Right Node with 7142 Examples
# Creating Left Child Node With 651 Examples, and Right Node with 1442 Examples
# Creating Left Child Node With 549 Examples, and Right Node with 102 Examples
# C(posterior=[],class=0,Purity=0.990892531876)
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=0,Purity=0.964632454924)
# Creating Left Child Node With 1789 Examples, and Right Node with 5353 Examples
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 432 Examples, and Right Node with 4921 Examples
# C(posterior=[],class=0,Purity=0.958333333333)
# C(posterior=[],class=2,Purity=0.891079048974)
# Creating Left Child Node With 11501 Examples, and Right Node with 5648 Examples
# Creating Left Child Node With 10549 Examples, and Right Node with 952 Examples
# Creating Left Child Node With 3517 Examples, and Right Node with 7032 Examples
# C(posterior=[],class=1,Purity=0.881148706284)
# C(posterior=[],class=1,Purity=0.480375426621)
# C(posterior=[],class=2,Purity=0.956932773109)
# Creating Left Child Node With 3390 Examples, and Right Node with 2258 Examples
# C(posterior=[],class=1,Purity=0.980530973451)
# C(posterior=[],class=0,Purity=0.999114260407)
# Creating Left Child Node With 461 Examples, and Right Node with 3155 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.990174326466)
# Creating Left Child Node With 10667 Examples, and Right Node with 19333 Examples
# Creating Left Child Node With 7386 Examples, and Right Node with 3281 Examples
# Creating Left Child Node With 515 Examples, and Right Node with 6871 Examples
# C(posterior=[],class=1,Purity=0.996116504854)
# Creating Left Child Node With 2494 Examples, and Right Node with 4377 Examples
# C(posterior=[],class=0,Purity=0.970328789094)
# Creating Left Child Node With 1551 Examples, and Right Node with 2826 Examples
# C(posterior=[],class=2,Purity=0.549967762734)
# C(posterior=[],class=0,Purity=0.946921443737)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 6529 Examples, and Right Node with 12804 Examples
# Creating Left Child Node With 2558 Examples, and Right Node with 3971 Examples
# Creating Left Child Node With 1622 Examples, and Right Node with 936 Examples
# Creating Left Child Node With 1488 Examples, and Right Node with 134 Examples
# C(posterior=[],class=0,Purity=0.946908602151)
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 2828 Examples, and Right Node with 1143 Examples
# Creating Left Child Node With 737 Examples, and Right Node with 2091 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.996174079388)
# Creating Left Child Node With 2 Examples, and Right Node with 1141 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.876424189308)
# Creating Left Child Node With 6370 Examples, and Right Node with 6434 Examples
# Creating Left Child Node With 1093 Examples, and Right Node with 5277 Examples
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 958 Examples, and Right Node with 4319 Examples
# C(posterior=[],class=1,Purity=0.701461377871)
# C(posterior=[],class=1,Purity=0.980319518407)
# Creating Left Child Node With 3032 Examples, and Right Node with 3402 Examples
# Creating Left Child Node With 996 Examples, and Right Node with 2036 Examples
# C(posterior=[],class=1,Purity=0.998995983936)
# C(posterior=[],class=2,Purity=0.898821218075)
# Creating Left Child Node With 170 Examples, and Right Node with 3232 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.541150990099)
# Creating Left Child Node With 20510 Examples, and Right Node with 9490 Examples
# Creating Left Child Node With 6727 Examples, and Right Node with 13783 Examples
# Creating Left Child Node With 5352 Examples, and Right Node with 1375 Examples
# Creating Left Child Node With 3143 Examples, and Right Node with 2209 Examples
# C(posterior=[],class=0,Purity=0.999045497932)
# Creating Left Child Node With 2209 Examples, and Right Node with 0 Examples
# C(posterior=[],class=0,Purity=0.533725667723)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 11646 Examples, and Right Node with 2137 Examples
# Creating Left Child Node With 11290 Examples, and Right Node with 356 Examples
# Creating Left Child Node With 2909 Examples, and Right Node with 8381 Examples
# C(posterior=[],class=2,Purity=0.506359573737)
# C(posterior=[],class=2,Purity=0.575349003699)
# Creating Left Child Node With 356 Examples, and Right Node with 0 Examples
# C(posterior=[],class=0,Purity=0.932584269663)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 4774 Examples, and Right Node with 4716 Examples
# C(posterior=[],class=1,Purity=0.99853372434)
# Creating Left Child Node With 4043 Examples, and Right Node with 673 Examples
# Creating Left Child Node With 2491 Examples, and Right Node with 1552 Examples
# Creating Left Child Node With 1654 Examples, and Right Node with 837 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 0 Examples, and Right Node with 1552 Examples
# C(posterior=[],class=2,Purity=0.917525773196)
# Creating Left Child Node With 631 Examples, and Right Node with 42 Examples
# C(posterior=[],class=2,Purity=0.984152139461)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 11331 Examples, and Right Node with 18669 Examples
# Creating Left Child Node With 7452 Examples, and Right Node with 3879 Examples
# Creating Left Child Node With 6641 Examples, and Right Node with 811 Examples
# Creating Left Child Node With 1610 Examples, and Right Node with 5031 Examples
# Creating Left Child Node With 344 Examples, and Right Node with 1266 Examples
# C(posterior=[],class=1,Purity=0.747093023256)
# C(posterior=[],class=2,Purity=0.996840442338)
# C(posterior=[],class=2,Purity=0.980123235937)
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=0,Purity=0.991750451147)
# Creating Left Child Node With 16087 Examples, and Right Node with 2582 Examples
# Creating Left Child Node With 4500 Examples, and Right Node with 11587 Examples
# C(posterior=[],class=1,Purity=0.996888888889)
# Creating Left Child Node With 9827 Examples, and Right Node with 1760 Examples
# Creating Left Child Node With 8544 Examples, and Right Node with 1283 Examples
# C(posterior=[],class=0,Purity=0.608848314607)
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=1,Purity=0.978409090909)
# Creating Left Child Node With 1834 Examples, and Right Node with 748 Examples
# C(posterior=[],class=2,Purity=0.995092693566)
# Creating Left Child Node With 22 Examples, and Right Node with 726 Examples
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 642 Examples, and Right Node with 84 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=1,Purity=0.52380952381)
# Creating Left Child Node With 11488 Examples, and Right Node with 18512 Examples
# Creating Left Child Node With 11488 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 8694 Examples, and Right Node with 2794 Examples
# Creating Left Child Node With 3441 Examples, and Right Node with 5253 Examples
# Creating Left Child Node With 2877 Examples, and Right Node with 564 Examples
# C(posterior=[],class=0,Purity=0.870351060132)
# C(posterior=[],class=2,Purity=0.998226950355)
# C(posterior=[],class=2,Purity=0.952979249952)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 2832 Examples, and Right Node with 15680 Examples
# C(posterior=[],class=2,Purity=0.991172316384)
# Creating Left Child Node With 6713 Examples, and Right Node with 8967 Examples
# Creating Left Child Node With 4376 Examples, and Right Node with 2337 Examples
# C(posterior=[],class=1,Purity=0.986517367459)
# Creating Left Child Node With 739 Examples, and Right Node with 1598 Examples
# C(posterior=[],class=1,Purity=0.61299052774)
# C(posterior=[],class=1,Purity=0.999374217772)
# Creating Left Child Node With 5754 Examples, and Right Node with 3213 Examples
# Creating Left Child Node With 2336 Examples, and Right Node with 3418 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.429490930369)
# Creating Left Child Node With 1642 Examples, and Right Node with 1571 Examples
# C(posterior=[],class=1,Purity=0.765529841657)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 5813 Examples, and Right Node with 24187 Examples
# Creating Left Child Node With 4669 Examples, and Right Node with 1144 Examples
# C(posterior=[],class=2,Purity=0.977082887128)
# Creating Left Child Node With 44 Examples, and Right Node with 1100 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=0,Purity=0.987272727273)
# Creating Left Child Node With 15567 Examples, and Right Node with 8620 Examples
# Creating Left Child Node With 8703 Examples, and Right Node with 6864 Examples
# Creating Left Child Node With 2246 Examples, and Right Node with 6457 Examples
# Creating Left Child Node With 1961 Examples, and Right Node with 285 Examples
# C(posterior=[],class=1,Purity=0.915349311576)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 1602 Examples, and Right Node with 4855 Examples
# C(posterior=[],class=0,Purity=0.991885143571)
# C(posterior=[],class=2,Purity=0.993614830072)
# Creating Left Child Node With 2632 Examples, and Right Node with 4232 Examples
# C(posterior=[],class=1,Purity=0.984042553191)
# Creating Left Child Node With 2455 Examples, and Right Node with 1777 Examples
# C(posterior=[],class=0,Purity=0.915274949084)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 2450 Examples, and Right Node with 6170 Examples
# C(posterior=[],class=0,Purity=0.984081632653)
# Creating Left Child Node With 3903 Examples, and Right Node with 2267 Examples
# Creating Left Child Node With 1700 Examples, and Right Node with 2203 Examples
# C(posterior=[],class=0,Purity=0.647058823529)
# C(posterior=[],class=1,Purity=0.991375397186)
# Creating Left Child Node With 1191 Examples, and Right Node with 1076 Examples
# C(posterior=[],class=1,Purity=0.688497061293)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 21493 Examples, and Right Node with 8507 Examples
# Creating Left Child Node With 15983 Examples, and Right Node with 5510 Examples
# Creating Left Child Node With 5970 Examples, and Right Node with 10013 Examples
# Creating Left Child Node With 1969 Examples, and Right Node with 4001 Examples
# Creating Left Child Node With 459 Examples, and Right Node with 1510 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.799337748344)
# C(posterior=[],class=1,Purity=0.98575356161)
# Creating Left Child Node With 6576 Examples, and Right Node with 3437 Examples
# Creating Left Child Node With 5593 Examples, and Right Node with 983 Examples
# C(posterior=[],class=2,Purity=0.760593599142)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 3316 Examples, and Right Node with 121 Examples
# C(posterior=[],class=0,Purity=0.652895054282)
# C(posterior=[],class=1,Purity=0.99173553719)
# Creating Left Child Node With 4737 Examples, and Right Node with 773 Examples
# Creating Left Child Node With 486 Examples, and Right Node with 4251 Examples
# Creating Left Child Node With 340 Examples, and Right Node with 146 Examples
# C(posterior=[],class=0,Purity=0.767647058824)
# C(posterior=[],class=2,Purity=0.965753424658)
# C(posterior=[],class=2,Purity=0.996000940955)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 2005 Examples, and Right Node with 6502 Examples
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 6379 Examples, and Right Node with 123 Examples
# Creating Left Child Node With 4073 Examples, and Right Node with 2306 Examples
# Creating Left Child Node With 2896 Examples, and Right Node with 1177 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=1,Purity=0.795242141037)
# Creating Left Child Node With 1784 Examples, and Right Node with 522 Examples
# C(posterior=[],class=0,Purity=0.984865470852)
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 7435 Examples, and Right Node with 22565 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 7435 Examples
# Creating Left Child Node With 2430 Examples, and Right Node with 5005 Examples
# Creating Left Child Node With 1204 Examples, and Right Node with 1226 Examples
# C(posterior=[],class=2,Purity=0.986710963455)
# Creating Left Child Node With 553 Examples, and Right Node with 673 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=2,Purity=0.91381872214)
# C(posterior=[],class=1,Purity=0.989210789211)
# Creating Left Child Node With 18825 Examples, and Right Node with 3740 Examples
# Creating Left Child Node With 7811 Examples, and Right Node with 11014 Examples
# Creating Left Child Node With 5694 Examples, and Right Node with 2117 Examples
# C(posterior=[],class=2,Purity=0.991394450299)
# Creating Left Child Node With 1056 Examples, and Right Node with 1061 Examples
# C(posterior=[],class=0,Purity=0.939393939394)
# C(posterior=[],class=0,Purity=0.793590951932)
# Creating Left Child Node With 7129 Examples, and Right Node with 3885 Examples
# Creating Left Child Node With 4225 Examples, and Right Node with 2904 Examples
# C(posterior=[],class=0,Purity=0.521893491124)
# C(posterior=[],class=0,Purity=0.762396694215)
# Creating Left Child Node With 3693 Examples, and Right Node with 192 Examples
# C(posterior=[],class=1,Purity=0.757649607365)
# C(posterior=[],class=2,Purity=0.640625)
# C(posterior=[],class=0,Purity=0.984759358289)
# Creating Left Child Node With 7458 Examples, and Right Node with 22542 Examples
# Creating Left Child Node With 2345 Examples, and Right Node with 5113 Examples
# C(posterior=[],class=2,Purity=0.959061833689)
# C(posterior=[],class=1,Purity=0.993154703696)
# Creating Left Child Node With 7168 Examples, and Right Node with 15374 Examples
# Creating Left Child Node With 3276 Examples, and Right Node with 3892 Examples
# Creating Left Child Node With 2113 Examples, and Right Node with 1163 Examples
# Creating Left Child Node With 273 Examples, and Right Node with 1840 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=0,Purity=0.885326086957)
# Creating Left Child Node With 1097 Examples, and Right Node with 66 Examples
# C(posterior=[],class=1,Purity=0.997265268915)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 2035 Examples, and Right Node with 1857 Examples
# Creating Left Child Node With 354 Examples, and Right Node with 1681 Examples
# C(posterior=[],class=2,Purity=0.590395480226)
# C(posterior=[],class=0,Purity=0.982153480071)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 2507 Examples, and Right Node with 12867 Examples
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 7751 Examples, and Right Node with 5116 Examples
# Creating Left Child Node With 6682 Examples, and Right Node with 1069 Examples
# C(posterior=[],class=1,Purity=0.486082011374)
# C(posterior=[],class=2,Purity=0.953227315248)
# C(posterior=[],class=2,Purity=0.985535574668)
# Creating Left Child Node With 5536 Examples, and Right Node with 24464 Examples
# Creating Left Child Node With 496 Examples, and Right Node with 5040 Examples
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 4446 Examples, and Right Node with 594 Examples
# Creating Left Child Node With 372 Examples, and Right Node with 4074 Examples
# C(posterior=[],class=0,Purity=0.954301075269)
# C(posterior=[],class=2,Purity=0.999509081983)
# Creating Left Child Node With 525 Examples, and Right Node with 69 Examples
# Creating Left Child Node With 449 Examples, and Right Node with 76 Examples
# C(posterior=[],class=2,Purity=0.547884187082)
# C(posterior=[],class=2,Purity=1.0)
# Creating Left Child Node With 69 Examples, and Right Node with 0 Examples
# C(posterior=[],class=2,Purity=0.855072463768)
# Creating Left Child Node With 5682 Examples, and Right Node with 18782 Examples
# C(posterior=[],class=1,Purity=0.989792326646)
# Creating Left Child Node With 7163 Examples, and Right Node with 11619 Examples
# Creating Left Child Node With 2020 Examples, and Right Node with 5143 Examples
# C(posterior=[],class=1,Purity=0.99801980198)
# Creating Left Child Node With 4327 Examples, and Right Node with 816 Examples
# C(posterior=[],class=0,Purity=0.948232031431)
# C(posterior=[],class=1,Purity=0.884803921569)
# Creating Left Child Node With 9137 Examples, and Right Node with 2482 Examples
# Creating Left Child Node With 5277 Examples, and Right Node with 3860 Examples
# C(posterior=[],class=2,Purity=0.678415766534)
# C(posterior=[],class=0,Purity=0.509585492228)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 7461 Examples, and Right Node with 22539 Examples
# Creating Left Child Node With 1886 Examples, and Right Node with 5575 Examples
# C(posterior=[],class=2,Purity=0.960763520679)
# C(posterior=[],class=1,Purity=0.989955156951)
# Creating Left Child Node With 3450 Examples, and Right Node with 19089 Examples
# Creating Left Child Node With 116 Examples, and Right Node with 3334 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 116 Examples
# Creating Left Child Node With 66 Examples, and Right Node with 50 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=0,Purity=0.6)
# Creating Left Child Node With 0 Examples, and Right Node with 3334 Examples
# Creating Left Child Node With 3070 Examples, and Right Node with 264 Examples
# C(posterior=[],class=0,Purity=0.938110749186)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 6551 Examples, and Right Node with 12538 Examples
# Creating Left Child Node With 955 Examples, and Right Node with 5596 Examples
# C(posterior=[],class=1,Purity=1.0)
# C(posterior=[],class=0,Purity=0.959971408149)
# Creating Left Child Node With 6744 Examples, and Right Node with 5794 Examples
# Creating Left Child Node With 4170 Examples, and Right Node with 2574 Examples
# C(posterior=[],class=2,Purity=0.393525179856)
# C(posterior=[],class=2,Purity=0.946386946387)
# Creating Left Child Node With 3229 Examples, and Right Node with 2565 Examples
# C(posterior=[],class=1,Purity=0.683803034995)
# C(posterior=[],class=2,Purity=0.99649122807)
# Creating Left Child Node With 25951 Examples, and Right Node with 4049 Examples
# Creating Left Child Node With 18692 Examples, and Right Node with 7259 Examples
# Creating Left Child Node With 13642 Examples, and Right Node with 5050 Examples
# Creating Left Child Node With 11779 Examples, and Right Node with 1863 Examples
# Creating Left Child Node With 2791 Examples, and Right Node with 8988 Examples
# C(posterior=[],class=0,Purity=0.999283410964)
# C(posterior=[],class=2,Purity=0.718847352025)
# C(posterior=[],class=0,Purity=0.994632313473)
# C(posterior=[],class=0,Purity=0.980198019802)
# Creating Left Child Node With 5197 Examples, and Right Node with 2062 Examples
# Creating Left Child Node With 1415 Examples, and Right Node with 3782 Examples
# C(posterior=[],class=1,Purity=1.0)
# Creating Left Child Node With 1823 Examples, and Right Node with 1959 Examples
# C(posterior=[],class=2,Purity=0.574876577071)
# C(posterior=[],class=1,Purity=0.825931597754)
# C(posterior=[],class=2,Purity=0.987875848691)
# C(posterior=[],class=1,Purity=0.996295381576)
# Creating Left Child Node With 4452 Examples, and Right Node with 25548 Examples
# C(posterior=[],class=1,Purity=0.980682839173)
# Creating Left Child Node With 15775 Examples, and Right Node with 9773 Examples
# Creating Left Child Node With 3137 Examples, and Right Node with 12638 Examples
# C(posterior=[],class=2,Purity=0.995537137392)
# Creating Left Child Node With 8192 Examples, and Right Node with 4446 Examples
# Creating Left Child Node With 5849 Examples, and Right Node with 2343 Examples
# C(posterior=[],class=0,Purity=0.798085142759)
# C(posterior=[],class=1,Purity=0.535638070849)
# C(posterior=[],class=1,Purity=0.966486729645)
# Creating Left Child Node With 1932 Examples, and Right Node with 7841 Examples
# C(posterior=[],class=0,Purity=0.964803312629)
# Creating Left Child Node With 6415 Examples, and Right Node with 1426 Examples
# Creating Left Child Node With 1748 Examples, and Right Node with 4667 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=2,Purity=0.612599100064)
# C(posterior=[],class=0,Purity=0.997194950912)
# Creating Left Child Node With 22610 Examples, and Right Node with 7390 Examples
# Creating Left Child Node With 12089 Examples, and Right Node with 10521 Examples
# Creating Left Child Node With 3552 Examples, and Right Node with 8537 Examples
# C(posterior=[],class=0,Purity=0.997184684685)
# Creating Left Child Node With 1877 Examples, and Right Node with 6660 Examples
# Creating Left Child Node With 556 Examples, and Right Node with 1321 Examples
# C(posterior=[],class=1,Purity=0.564748201439)
# C(posterior=[],class=0,Purity=0.999242997729)
# Creating Left Child Node With 529 Examples, and Right Node with 6131 Examples
# C(posterior=[],class=0,Purity=1.0)
# C(posterior=[],class=2,Purity=0.985157396836)
# Creating Left Child Node With 4899 Examples, and Right Node with 5622 Examples
# Creating Left Child Node With 4106 Examples, and Right Node with 793 Examples
# Creating Left Child Node With 1920 Examples, and Right Node with 2186 Examples
# C(posterior=[],class=0,Purity=0.999479166667)
# C(posterior=[],class=0,Purity=0.602012808783)
# Creating Left Child Node With 660 Examples, and Right Node with 133 Examples
# C(posterior=[],class=1,Purity=0.99696969697)
# C(posterior=[],class=0,Purity=1.0)
# Creating Left Child Node With 4296 Examples, and Right Node with 1326 Examples
# Creating Left Child Node With 933 Examples, and Right Node with 3363 Examples
# C(posterior=[],class=2,Purity=1.0)
# C(posterior=[],class=1,Purity=0.992566161166)
# Creating Left Child Node With 0 Examples, and Right Node with 1326 Examples
# C(posterior=[],class=0,Purity=0.674962292609)
# Creating Left Child Node With 5619 Examples, and Right Node with 1771 Examples
# C(posterior=[],class=1,Purity=0.987008364478)
# C(posterior=[],class=2,Purity=0.998870694523)

# %%
#Training Confusion Matrix
Yp=rfc.predict(X)
print Y.shape, len(Yp)
t.print_confusion_matrix(Yp,Y)
# Out:
# (30000L,) 30000
# Predicted      0     1     2    All
# Actual
# 0           9954     2    44  10000
# 1            162  9717   121  10000
# 2            262    56  9682  10000
# All        10378  9775  9847  30000

# %%
#Testing Confusion Matrix
Ypt=rfc.predict(Xtest)
print Y.shape, len(Ypt)
t.print_confusion_matrix(Ypt,Ytest)
# Out:
# (30000L,) 15000
# Predicted     0     1     2    All
# Actual
# 0          4973     3    24   5000
# 1            75  4859    66   5000
# 2           126    33  4841   5000
# All        5174  4895  4931  15000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Y.flatten() ==  np.array(Yp)) / float(Y.shape[0]) 

assert_greater_equal(acc, 0.78)

# %%
t.plot_points_range(rfc,X,Y)
# Out:
# (10000L, 2L)
# [0, 1, 2]

# %%
t.plot_decision_regions(X,Y,rfc,res=0.1)

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
ntrees=rfc.ntrees
nrows=ntrees/2
ncols=2
i=1
plt.subplots(nrows,ncols,figsize=(16,40))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    t.plot_decision_regions(X,Y,clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# ## TODO: Find Optimal Number of Trees for this data set, using cross validation...

# %%
X,Y=t.get_spherical_data(N=10000)
print X.shape, Y.shape
Xtest,Ytest=t.get_spherical_data(N=5000)

trees = np.arange(1, 21)

for tree in trees:
    rfc=rf.RandomForest(weaklearner='Linear',usebagging=False,ntrees=tree)
    rfc.train(X,Y[:,np.newaxis])

    Ypt=rfc.predict(Xtest)

    acc = np.sum(Ytest ==  np.array(Ypt)) / float(Ytest.shape[0]) 

    print "Trees=", tree, " and Accuracy=", acc
